# %% [markdown]
# <a href="https://colab.research.google.com/github/williamkilpatrick/Reinforcement-Learning-for-Financial-Trading/blob/main/Transformer_PPO_Trading_Agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Notebook Summary: Reinforcement Learning for Financial Trading
#
# This notebook demonstrates the implementation of a reinforcement learning-based trading strategy using a Transformer model and the Gymnasium framework (maintained fork of the OpenAI Gym framework).
#
# **At a basic level, the notebook does the following:**
#
# 1. **Sets up the environment:** Installs necessary libraries and checks for GPU availability.
# 2. **Loads and preprocesses financial data:** Reads historical market data from a CSV file, scales numerical features, and engineers features for the model. The data is then split into training and testing sets.
# 3. **Defines a Transformer model:** Creates a custom Transformer model architecture specifically designed for financial trading. This model will learn to predict buy/sell signals based on market data patterns.
# 4. **Defines a trading environment:** Sets up a simulated trading environment using Gymnasium, allowing the agent to interact with the market and receive rewards based on its trading decisions.
# 5. **Trains a PPO agent:** Trains a Proximal Policy Optimization (PPO) agent within the trading environment. The agent learns by interacting with the environment and adjusting its actions to maximize profits.
# 6. **Tests the trained agent:** Loads the trained agent and tests its performance in the simulated trading environment, evaluating its ability to make profitable trades.
# 7. **Displays the final results:** Shows the agent's final balance and the total number of trades executed during the test, providing an overall assessment of its trading strategy.
#
# **In essence, this notebook aims to develop and evaluate a reinforcement learning-based trading agent that can learn to make profitable trading decisions based on historical market data.** The Transformer model is used to capture complex patterns in the data, and the PPO algorithm guides the agent's learning process. The simulated trading environment provides a safe and controlled setting for the agent to experiment and improve its strategy.

# %% [markdown]
# ## Install Packages
#
# **Summary:** This cell sets up the environment by installing the required dependencies (`stable-baselines3` and `shimmy`) for reinforcement learning and compatibility. This ensures that the rest of the code in the notebook can run without issues related to missing libraries.

# %%
# !pip install stable-baselines3 shimmy>=2.0

# %% [markdown]
# ## Importing Necessary Libraries
#
# This cell imports essential libraries for data science, machine learning, and reinforcement learning tasks in the context of financial analysis.
#
# **Steps:**
#
# 1. **Import Core Libraries:**
#    - `import torch`: Imports the PyTorch library, a powerful framework for deep learning and numerical computation.
#    - `import torch.nn as nn`: Imports the `nn` module from PyTorch, which provides building blocks for neural networks.
#    - `import numpy as np`: Imports NumPy, a fundamental library for numerical operations and array handling.
#    - `import pandas as pd`: Imports pandas, a library for data manipulation and analysis using DataFrames.
#    - `from sklearn.preprocessing import StandardScaler`: Imports `StandardScaler` from scikit-learn, used for feature scaling.
#    - `from torch.utils.data import Dataset, DataLoader`: Imports `Dataset` and `DataLoader` from PyTorch, used for creating and handling datasets.
#    - `import gymnasium as gym`: Imports the Gymnasium library, a maintained fork of the OpenAI Gym framework. This library provides tools for developing and comparing reinforcement learning algorithms.
#    - `from gymnasium import spaces`: Imports the `spaces` module from Gymnasium. This module is used to define the action and observation spaces for reinforcement learning environments.
#    - `from stable_baselines3 import PPO`: Imports the PPO (Proximal Policy Optimization) algorithm from the `stable_baselines3` library, a popular reinforcement learning algorithm.
#    - `import shimmy`: Imports the `shimmy` library for compatibility between different library versions.
#
# **Summary:** This cell imports a collection of libraries that provide the necessary tools and functionalities for tasks such as data handling, preprocessing, model building, training, and reinforcement learning.

# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from torch.utils.data import Dataset, DataLoader
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
import shimmy

# %% [markdown]
# ## Checking for GPU Availability
#
# This cell checks if a GPU is available for computation and prints the device being used.
#
# **Steps:**
#
# 1. **Device Detection:**
#    - `device = torch.device("cuda" if torch.cuda.is_available() else "cpu")`: This line uses the `torch.cuda.is_available()` function to determine if a CUDA-enabled GPU is present.
#    - If a GPU is available, it assigns the device to "cuda"; otherwise, it defaults to "cpu".
#
# 2. **Output:**
#    - `print(f"Using device: {device}")`: Prints a message indicating whether the code will be running on a GPU ("cuda") or CPU ("cpu").
#
# **Summary:** This cell checks for the availability of a GPU and sets the device accordingly, ensuring that the code utilizes the appropriate hardware for computation. This can significantly speed up training and execution, especially for computationally intensive tasks like deep learning.

# %%
# Check for GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ## Data Loading and Preprocessing
#
# This cell prepares the financial data for the machine learning model.
#
# **Steps:**
#
# 1. **Import Libraries:** Imports `pandas` for data manipulation.
#
# 2. **Load Data:** Reads a CSV file containing historical market data into a pandas DataFrame.
#
# 3. **Data Preprocessing with `preprocess_data` Function:**
#     - **Scaling:** Uses `StandardScaler` to scale numerical features (Open, High, Low, Close, Volume, etc.) for improved model performance.
#     - **Feature Engineering:** Creates input (X) and output (y) data:
#         - **Input (X):** Sequences of historical data points (length defined by `seq_length`, default 100) representing past market behavior.
#         - **Output (y):** Binary labels (0 or 1) indicating Buy (1) or Sell (0) based on future price movement.
#     - **Output:** Returns prepared X and y as NumPy arrays.
#
# 4. **Prepare Dataset:**
#     - Calls `preprocess_data` to create X and y.
#     - Splits the data into training (80%) and testing (20%) sets.
#
# **Summary:** This cell loads, cleans, scales, engineers features, and splits the data for training and testing the model.

# %%
# Load Data
df = pd.read_csv('/content/ES - 1 min.csv')
df.fillna(0, inplace=True)

def preprocess_data(df, seq_length=200):
    scaler = StandardScaler()
    features = ['Open', 'High', 'Low', 'Close', 'Volume', 'Range', '%K(Fast)(14)', '%D(Fast)(14,3)',
                'VWMA(C,20)', '%K(Fast)(9)', '%D(Fast)(9,3)', '%K(Fast)(40)', '%D(Fast)(40,4)',
                '%K(Full)(60,10)', '%D(Full)(60,10,10)', 'ATR(14)']

    df[features] = scaler.fit_transform(df[features])

    X, y = [], []
    for i in range(len(df) - seq_length - 1):
        X.append(df[features].iloc[i:i+seq_length].values)
        future_close = df['Close'].iloc[i + seq_length]
        current_close = df['Close'].iloc[i + seq_length - 1]
        y.append(1 if future_close > current_close else 0)  # 1 = Buy, 0 = Sell

    return np.array(X), np.array(y)

# Prepare dataset
X, y = preprocess_data(df)
train_size = int(0.8 * len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %% [markdown]
# ## Creating and Loading Data with PyTorch
#
# This cell defines a custom dataset class `FuturesDataset` and creates data loaders for training and testing using PyTorch.
#
# **Steps:**
#
# 1. **Define `FuturesDataset`:**
#    - This class inherits from `torch.utils.data.Dataset` and is designed to handle the financial data.
#    - It takes the input features (`X`) and target labels (`y`) as NumPy arrays and converts them into PyTorch tensors.
#    - It implements the `__len__` and `__getitem__` methods to enable iterating over the dataset and accessing individual data points.
#
# 2. **Create Data Loaders:**
#    - `train_loader`: This data loader is created for the training dataset using `DataLoader`.
#      - It shuffles the data (`shuffle=True`) to randomize the order of samples during training.
#      - It uses multiple workers (`num_workers=4`) to load data in parallel, speeding up the process.
#      - It sets `pin_memory=True` to optimize memory transfer between the CPU and GPU.
#    - `test_loader`: This data loader is created for the testing dataset.
#      - It does not shuffle the data (`shuffle=False`) to maintain a consistent order for evaluation.
#      - It also uses multiple workers and pins memory for efficiency.
#
# **Summary:** This cell prepares the data for use with PyTorch by creating a custom dataset class and data loaders. This allows for efficient batching and loading of data during training and testing of the model.

# %%
class FuturesDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %% [markdown]
# ## Creating Data Loaders for Efficient Data Handling
#
# This code snippet creates two data loaders, `train_loader` and `test_loader`, using PyTorch's `DataLoader` class. These data loaders are essential for efficiently feeding data to the machine learning model during training and evaluation.
#
# **Purpose:**
#
# The primary purpose of this code is to:
#
# 1. **Prepare data for training and testing:** It takes the training data (`X_train`, `y_train`) and testing data (`X_test`, `y_test`) and packages them into iterable objects called data loaders.
# 2. **Enable batch processing:** Data loaders divide the data into smaller batches, allowing the model to process data in chunks, which is more memory-efficient and often faster.
# 3. **Optimize data loading:** It uses multiple worker processes (`num_workers=4`) to load data in parallel, speeding up the data loading process, especially for large datasets.
# 4. **Improve GPU utilization:** It sets `pin_memory=True` to optimize data transfer between the CPU and GPU, potentially reducing data transfer overhead.
#
# **Data Loaders:**
#
# - **`train_loader`:**
#     - Used for training the model.
#     - Shuffles the data (`shuffle=True`) to randomize the order of samples in each epoch, improving model generalization.
# - **`test_loader`:**
#     - Used for evaluating the model's performance.
#     - Does not shuffle the data (`shuffle=False`) to ensure consistent evaluation across different runs.
#
# **Parameters:**
#
# - `FuturesDataset(X_train, y_train)` and `FuturesDataset(X_test, y_test)`: Instances of a custom dataset class (presumably defined earlier in the code) that encapsulate the training and testing data.
# - `batch_size=64`: Specifies the number of samples in each batch.
# - `shuffle=True` (for `train_loader`) and `shuffle=False` (for `test_loader`): Controls whether the data is shuffled within each epoch.
# - `num_workers=4`: Sets the number of worker processes to use for data loading.
# - `pin_memory=True`: Enables memory pinning, which can speed up data transfer to the GPU.
#
# **Summary:**
#
# This code snippet creates data loaders for training and testing, enabling efficient and optimized data handling during the machine learning process. It utilizes batching, shuffling, parallel data loading, and memory pinning to streamline data processing and potentially improve model training speed and performance.

# %%
# Use multiple workers for faster data loading
train_loader = DataLoader(FuturesDataset(X_train, y_train), batch_size=64, shuffle=True, num_workers=4, pin_memory=True)
test_loader = DataLoader(FuturesDataset(X_test, y_test), batch_size=64, shuffle=False, num_workers=4, pin_memory=True)

# %% [markdown]
# ## Defining the Trading Transformer Model
#
# This cell defines the architecture of a Transformer model specifically designed for financial trading.
#
# **Steps:**
#
# 1. **Class Definition:**
#    - `TradingTransformer(nn.Module)`: A custom class inheriting from PyTorch's `nn.Module` is defined to represent the trading model.
#
# 2. **Initialization (`__init__`)**:
#     - `input_dim`: Specifies the dimensionality of the input data.
#     - `num_heads`: Sets the number of attention heads in the Transformer encoder layers (default: 4).
#     - `num_layers`: Determines the number of stacked encoder layers (default: 2).
#     - `hidden_dim`: Sets the size of the hidden layer in the feed-forward network (default: 128).
#     - **Layers:**
#         - `nn.TransformerEncoderLayer`: Creates a Transformer encoder layer with specified parameters.
#         - `nn.TransformerEncoder`: Stacks multiple encoder layers to form the main Transformer encoder.
#         - `nn.Linear`: Defines fully connected layers for the input and output.
#         - `nn.ReLU`: Introduces a ReLU activation function for non-linearity.
#
# 3. **Forward Pass (`forward`)**:
#     - Defines how the data flows through the model during inference or training.
#     - `x`: Input tensor representing the financial data sequence.
#     - Processing:
#         - `self.transformer_encoder(x)`: Passes the input through the Transformer encoder.
#         - `x[:, -1, :]`: Selects the output from the last time step of the encoder.
#         - `self.relu(self.fc(x))`: Applies a fully connected layer and ReLU activation.
#         - `self.output_layer(x)`: Produces the final output, likely a prediction for buy/sell.
#
# **Summary:** This cell constructs a Transformer-based neural network model designed for financial trading. It defines the model's architecture, including the layers, activation functions, and how data is processed during both training and inference. The model learns patterns and relationships in financial data to make trading decisions.

# %%
# Transformer Model optimized for GPU
class TradingTransformer(nn.Module):
    def __init__(self, input_dim, num_heads=4, num_layers=2, hidden_dim=128):
        super(TradingTransformer, self).__init__()
        self.encoder_layer = nn.TransformerEncoderLayer(d_model=input_dim, nhead=num_heads, batch_first=True)
        self.transformer_encoder = nn.TransformerEncoder(self.encoder_layer, num_layers=num_layers)
        self.fc = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.output_layer = nn.Linear(hidden_dim, 2)  # Buy/Sell classification

    def forward(self, x):
        x = self.transformer_encoder(x)
        x = x[:, -1, :]  # Take the last time step's output
        x = self.relu(self.fc(x))
        return self.output_layer(x)

# %% [markdown]
# ## Training and Saving the Trading Transformer Model
#
# This cell focuses on training the defined Trading Transformer model and saving it for later use.
#
# **Steps:**
#
# 1. **Model Initialization and Setup:**
#    - `model = TradingTransformer(input_dim=X.shape[2]).to(device)`: Creates an instance of the `TradingTransformer` model, setting the input dimension based on the data shape (`X.shape[2]`). It then moves the model to the appropriate device (GPU if available, otherwise CPU).
#    - `optimizer = torch.optim.Adam(model.parameters(), lr=0.001)`: Initializes an Adam optimizer to update the model's parameters during training. The learning rate is set to 0.001.
#    - `criterion = nn.CrossEntropyLoss()`: Defines the loss function to measure the difference between the model's predictions and the actual target labels. CrossEntropyLoss is commonly used for classification tasks.
#    - `scaler = torch.cuda.amp.GradScaler()`: Creates a GradScaler for Automatic Mixed Precision (AMP) training, potentially improving performance and reducing memory usage on compatible GPUs.
#
# 2. **Training Loop (`train_model`)**:
#    - `model.train()`: Sets the model to training mode, enabling necessary behaviors like dropout and batch normalization.
#    - Iterates through epochs (specified by `epochs` parameter, default 25):
#      - Iterates through batches of data from the `train_loader`:
#        - `X_batch, y_batch = X_batch.to(device), y_batch.to(device)`: Moves the input data and target labels to the appropriate device.
#        - `optimizer.zero_grad()`: Resets the gradients of the optimizer before each iteration.
#        - **Forward Pass and Loss Calculation:**
#          - `with torch.cuda.amp.autocast()`: Enables automatic mixed precision for the forward pass.
#          - `outputs = model(X_batch)`: Passes the input batch through the model to get predictions.
#          - `loss = criterion(outputs, y_batch)`: Calculates the loss between predictions and actual labels.
#        - **Backward Pass and Optimization:**
#          - `scaler.scale(loss).backward()`: Scales the loss and performs backpropagation to calculate gradients.
#          - `scaler.step(optimizer)`: Updates the model's parameters using the optimizer.
#          - `scaler.update()`: Updates the GradScaler state.
#        - `total_loss += loss.item()`: Accumulates the loss for the epoch.
#      - Prints the average loss for the epoch.
#
# 3. **Saving the Model:**
#    - `torch.save(model.state_dict(), 'trading_transformer.pth')`: Saves the trained model's state dictionary (containing model weights and biases) to a file named 'trading_transformer.pth'. This allows you to load and reuse the trained model later.
#
# **Summary:** This cell trains the Trading Transformer model using the provided training data and saves the trained model's weights to a file. It sets up the necessary components for training, including the optimizer, loss function, and data loaders. The training loop iterates through epochs and batches, updating the model's parameters to minimize the loss. Finally, it saves the trained model for future use.

# %%
# Move model to GPU
model = TradingTransformer(input_dim=X.shape[2]).to(device)

# Optimizer and loss function
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# Training with Mixed Precision (AMP)
scaler = torch.amp.GradScaler()

def train_model(model, train_loader, epochs=25):
    model.train()
    for epoch in range(epochs):
        total_loss = 0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)

            optimizer.zero_grad()

            with torch.amp.autocast(device_type=device.type):
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            total_loss += loss.item()

        print(f'Epoch {epoch+1}, Loss: {total_loss/len(train_loader):.4f}')

# Train the model
train_model(model, train_loader)

# Save model
torch.save(model.state_dict(), 'trading_transformer.pth')
# Out:
# Epoch 1, Loss: 0.6942
# Epoch 2, Loss: 0.6897
# Epoch 3, Loss: 0.6880
# Epoch 4, Loss: 0.6887
# Epoch 5, Loss: 0.6880
# Epoch 6, Loss: 0.6853
# Epoch 7, Loss: 0.6877
# Epoch 8, Loss: 0.6850
# Epoch 9, Loss: 0.6862
# Epoch 10, Loss: 0.6838
# Epoch 11, Loss: 0.6833
# Epoch 12, Loss: 0.6816
# Epoch 13, Loss: 0.6781
# Epoch 14, Loss: 0.6814
# Epoch 15, Loss: 0.6778
# Epoch 16, Loss: 0.6796
# Epoch 17, Loss: 0.6761
# Epoch 18, Loss: 0.6756
# Epoch 19, Loss: 0.6718
# Epoch 20, Loss: 0.6727
# Epoch 21, Loss: 0.6697
# Epoch 22, Loss: 0.6696
# Epoch 23, Loss: 0.6713
# Epoch 24, Loss: 0.6671
# Epoch 25, Loss: 0.6726

# %% [markdown]
# ## Defining the Trading Environment
#
# This cell defines a custom trading environment called `TradingEnv`, which simulates the interactions of a trading agent with the financial market. It uses the OpenAI Gym framework to structure the environment, allowing the agent to learn through reinforcement learning.
#
# **Steps:**
#
# 1. **Environment Initialization (`__init__`)**:
#    - `df`: The DataFrame containing the market data used for the simulation.
#    - `initial_balance`: The starting capital for the trading agent.
#    - `tick_size`: The minimum price movement of the asset being traded.
#    - `tick_value`: The profit or loss associated with a one-tick price change.
#    - Other variables like `balance`, `current_step`, `position`, and `total_trades` are initialized to track the agent's state.
#    - **Action Space:** Defines the possible actions the agent can take (likely Hold, Buy, Sell).
#    - **Observation Space:** Defines the information the agent receives about the market (e.g., current price, indicators, etc.).
#
# 2. **Environment Methods:**
#    - `reset()`: Resets the environment to its initial state for a new episode.
#    - `_next_observation()`: Returns the current market state to the agent.
#    - `step(action)`: Executes the agent's action, updates the environment state, and returns the new observation, reward, done flag, and additional information.
#    - `render()`: Displays information about the environment, such as the current balance and position.
#
# **Handling Potential Issues:**
# - The code includes mechanisms to handle potential issues with the data:
#     - **NaN/inf values:** It replaces infinite or missing values in the DataFrame with appropriate values to avoid errors during training.
#     - **Forward Filling:** It uses forward filling to fill in any remaining missing values after handling infinite values.
#
# **Summary:**
#
# This cell creates a custom trading environment that simulates market dynamics and allows a trading agent to interact with it. It defines the actions the agent can take, the information it receives, and how the environment's state changes in response to the agent's actions. This environment serves as a crucial component for training a reinforcement learning agent for financial trading.

# %%
class TradingEnv(gym.Env):
    def __init__(self, df, initial_balance=10000, tick_size=0.25, tick_value=12.50):
        super(TradingEnv, self).__init__()

        self.df = df.reset_index(drop=True)
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.current_step = 0
        self.tick_size = tick_size
        self.tick_value = tick_value
        self.position = 0  # 1 = long, -1 = short, 0 = no position
        self.total_trades = 0

        # Define action & observation space
        self.action_space = spaces.Discrete(3)  # 0 = Hold, 1 = Buy, 2 = Sell

        # Fix NaN and infinite values
        self.df.replace([np.inf, -np.inf], np.nan, inplace=True)
        self.df = self.df.ffill()

        # Fix observation space (explicit float32 conversion)
        self.observation_space = spaces.Box(
            low=self.df.min().values.astype(np.float32),
            high=self.df.max().values.astype(np.float32),
            shape=(len(self.df.columns),),
            dtype=np.float32
        )

    def reset(self, seed=None, options=None):
        """Reset the environment for a new episode."""
        super().reset(seed=seed)  # Gymnasium requires this
        self.balance = self.initial_balance
        self.current_step = 0
        self.position = 0
        self.total_trades = 0
        return self._next_observation(), {}  # Gymnasium requires (obs, info)

    def _next_observation(self):
        """Return the next market state."""
        return self.df.iloc[self.current_step].values.astype(np.float32)

    def step(self, action):
        """Execute the action and return new state, reward, done."""
        self.current_step += 1
        if self.current_step >= len(self.df) - 1:
            return self._next_observation(), 0, True, False, {}  # Done if out of data

        prev_close = self.df.iloc[self.current_step - 1]['Close']
        new_close = self.df.iloc[self.current_step]['Close']
        price_change = (new_close - prev_close) / self.tick_size  # Price movement in ticks
        profit_loss = price_change * self.tick_value  # P&L per tick

        reward = 0  # Default reward

        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.total_trades += 1
            elif self.position == -1:  # Closing a short
                self.balance += profit_loss
                reward = profit_loss
                self.position = 0

        elif action == 2:  # Sell
            if self.position == 0:
                self.position = -1
                self.total_trades += 1
            elif self.position == 1:  # Closing a long
                self.balance += profit_loss
                reward = profit_loss
                self.position = 0

        # Fix termination conditions for Gymnasium
        terminated = self.current_step >= len(self.df) - 1  # If episode naturally ends
        truncated = self.balance <= 0  # If forced to end due to balance loss

        return self._next_observation(), reward, terminated, truncated, {}

    def render(self):
        print(f'Step: {self.current_step}, Balance: {self.balance:.2f}, Position: {self.position}')

# %% [markdown]
# ## Training and Saving the PPO Agent
#
# This cell focuses on training a Proximal Policy Optimization (PPO) agent within the defined trading environment and saving the trained agent for later use.
#
# **Steps:**
#
# 1. **Environment and Agent Setup:**
#     - `env = TradingEnv(df)`: Creates an instance of the `TradingEnv` environment using the loaded financial data (`df`).
#     - `model = PPO("MlpPolicy", env, verbose=1)`: Creates a PPO agent using the `MlpPolicy` (Multi-Layer Perceptron policy), specifying the environment and enabling verbose output (`verbose=1`) to track training progress.
#
# 2. **Training the Agent:**
#     - `model.learn(total_timesteps=100000)`: Trains the PPO agent for a specified number of timesteps (100,000 in this case). During training, the agent interacts with the environment, learns from its experiences, and updates its policy to maximize rewards (profit in the trading context).
#
# 3. **Saving the Trained Agent:**
#     - `model.save("ppo_trading_agent")`: Saves the trained PPO agent to a file named "ppo_trading_agent". This allows you to load and reuse the trained agent later without retraining.
#
# **Summary:**
#
# This cell sets up a trading environment, creates a PPO reinforcement learning agent, trains the agent within the environment to learn a profitable trading strategy, and saves the trained agent for future use. The PPO algorithm is a popular choice for reinforcement learning due to its stability and efficiency. Saving the trained agent enables you to apply the learned strategy to new market data or continue training from where it left off.

# %%
# Load dataset
df = pd.read_csv("/content/ES - 1 min.csv")
df.fillna(0, inplace=True)
df = df.drop(columns=["Date"])

env = TradingEnv(df)

# Create PPO agent
model = PPO("MlpPolicy", env, verbose=1, device="cpu")

# Train the model
model.learn(total_timesteps=100000)

# Save trained model
model.save("ppo_trading_agent")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1069 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | 4.11e+03     |
# | time/                   |              |
# |    fps                  | 828          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0046434654 |
# |    clip_fraction        | 0.0115       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.000218    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.01e+04     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 2.47e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 4.11e+03    |
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007884636 |
# |    clip_fraction        | 0.0235      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.000274   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.56e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00114    |
# |    value_loss           | 1.18e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 1.28e+03    |
# | time/                   |             |
# |    fps                  | 744         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.005053446 |
# |    clip_fraction        | 0.0268      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.00106     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.16e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00194    |
# |    value_loss           | 1.34e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 1.28e+03    |
# | time/                   |             |
# |    fps                  | 730         |
# |    iterations           | 5           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009274973 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.00468    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.52e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00221    |
# |    value_loss           | 1e+04       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 942         |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 6           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.004043878 |
# |    clip_fraction        | 0.0309      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.000308   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.96e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00165    |
# |    value_loss           | 1.54e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | 994          |
# | time/                   |              |
# |    fps                  | 714          |
# |    iterations           | 7            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0075565754 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.000464    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.99e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00218     |
# |    value_loss           | 1.16e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | 994          |
# | time/                   |              |
# |    fps                  | 710          |
# |    iterations           | 8            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0026240135 |
# |    clip_fraction        | 0.0745       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.00141     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.99e+03     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00224     |
# |    value_loss           | 8.58e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 1.66e+03    |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 9           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011913167 |
# |    clip_fraction        | 0.0157      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00179    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.37e+04    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.000605   |
# |    value_loss           | 2.1e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 1.66e+03    |
# | time/                   |             |
# |    fps                  | 703         |
# |    iterations           | 10          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004675069 |
# |    clip_fraction        | 0.0302      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.000207    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.74e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.00149     |
# |    value_loss           | 9.52e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 1.11e+03    |
# | time/                   |             |
# |    fps                  | 698         |
# |    iterations           | 11          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014985159 |
# |    clip_fraction        | 0.0402      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.000471    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.66e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00368    |
# |    value_loss           | 1.33e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 1.11e+03    |
# | time/                   |             |
# |    fps                  | 696         |
# |    iterations           | 12          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.011043165 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.00311     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.43e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00181    |
# |    value_loss           | 1.39e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | 709          |
# | time/                   |              |
# |    fps                  | 695          |
# |    iterations           | 13           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0063898247 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.00731      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.01e+04     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00242     |
# |    value_loss           | 1.13e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 712         |
# | time/                   |             |
# |    fps                  | 693         |
# |    iterations           | 14          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011156863 |
# |    clip_fraction        | 0.0515      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.00126    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.28e+04    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00482    |
# |    value_loss           | 1.97e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 712         |
# | time/                   |             |
# |    fps                  | 692         |
# |    iterations           | 15          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012223755 |
# |    clip_fraction        | 0.0475      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00256    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.54e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00537    |
# |    value_loss           | 7.45e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 812         |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 16          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011707882 |
# |    clip_fraction        | 0.0553      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.0005     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11e+04    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0058     |
# |    value_loss           | 1.78e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 812         |
# | time/                   |             |
# |    fps                  | 690         |
# |    iterations           | 17          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.015518702 |
# |    clip_fraction        | 0.0762      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.00087     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.05e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00361    |
# |    value_loss           | 9.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 656         |
# | time/                   |             |
# |    fps                  | 688         |
# |    iterations           | 18          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004438628 |
# |    clip_fraction        | 0.00996     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.0059     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.96e+03    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00182    |
# |    value_loss           | 1.69e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | 656          |
# | time/                   |              |
# |    fps                  | 686          |
# |    iterations           | 19           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0038553562 |
# |    clip_fraction        | 0.054        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.000577    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.77e+03     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00188     |
# |    value_loss           | 8.85e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | 347          |
# | time/                   |              |
# |    fps                  | 685          |
# |    iterations           | 20           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0051979627 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.000437    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.62e+04     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000606    |
# |    value_loss           | 1.97e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 302         |
# | time/                   |             |
# |    fps                  | 685         |
# |    iterations           | 21          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009458464 |
# |    clip_fraction        | 0.0185      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00338    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.34e+03    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00334    |
# |    value_loss           | 1.35e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 302         |
# | time/                   |             |
# |    fps                  | 684         |
# |    iterations           | 22          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008230207 |
# |    clip_fraction        | 0.0449      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.00682     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.62e+03    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00312    |
# |    value_loss           | 1.27e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 107         |
# | time/                   |             |
# |    fps                  | 683         |
# |    iterations           | 23          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009452147 |
# |    clip_fraction        | 0.0341      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.0141      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.05e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00409    |
# |    value_loss           | 1.75e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 107         |
# | time/                   |             |
# |    fps                  | 682         |
# |    iterations           | 24          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.014850777 |
# |    clip_fraction        | 0.0531      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00246    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.78e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00367    |
# |    value_loss           | 8.06e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | 24.1         |
# | time/                   |              |
# |    fps                  | 682          |
# |    iterations           | 25           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0071411016 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.00844      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.46e+03     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 1.17e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 24.1        |
# | time/                   |             |
# |    fps                  | 681         |
# |    iterations           | 26          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.012817738 |
# |    clip_fraction        | 0.093       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.00468     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.44e+03    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00245    |
# |    value_loss           | 1.03e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.56e+03   |
# |    ep_rew_mean          | 108        |
# | time/                   |            |
# |    fps                  | 681        |
# |    iterations           | 27         |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.00405016 |
# |    clip_fraction        | 0.00776    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | -0.00575   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.23e+04   |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.00131   |
# |    value_loss           | 1.44e+04   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | 116          |
# | time/                   |              |
# |    fps                  | 681          |
# |    iterations           | 28           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0009510808 |
# |    clip_fraction        | 0.000537     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.000364    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.68e+04     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000582    |
# |    value_loss           | 2.46e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 681         |
# |    iterations           | 29          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.010628657 |
# |    clip_fraction        | 0.0406      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.00471     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.18e+03    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00345    |
# |    value_loss           | 8.64e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 59.6        |
# | time/                   |             |
# |    fps                  | 680         |
# |    iterations           | 30          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.012108626 |
# |    clip_fraction        | 0.0283      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.00485    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.64e+03    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00192    |
# |    value_loss           | 1.07e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 59.6        |
# | time/                   |             |
# |    fps                  | 680         |
# |    iterations           | 31          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.015487932 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0142      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.18e+03    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00407    |
# |    value_loss           | 1.01e+04    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.56e+03      |
# |    ep_rew_mean          | 112           |
# | time/                   |               |
# |    fps                  | 680           |
# |    iterations           | 32            |
# |    time_elapsed         | 96            |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.00034383914 |
# |    clip_fraction        | 0.00181       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.07         |
# |    explained_variance   | 0.0147        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.59e+03      |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000147     |
# |    value_loss           | 1.1e+04       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 112         |
# | time/                   |             |
# |    fps                  | 680         |
# |    iterations           | 33          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.003365726 |
# |    clip_fraction        | 0.0125      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.0188      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.08e+03    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.000753   |
# |    value_loss           | 7.92e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | -96.1       |
# | time/                   |             |
# |    fps                  | 679         |
# |    iterations           | 34          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.002103268 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0196      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.24e+03    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.000388    |
# |    value_loss           | 1.68e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | -3.75        |
# | time/                   |              |
# |    fps                  | 679          |
# |    iterations           | 35           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0075308084 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.0232      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.64e+03     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00066     |
# |    value_loss           | 1.79e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | -3.75        |
# | time/                   |              |
# |    fps                  | 679          |
# |    iterations           | 36           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0015187748 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.00673      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.82e+03     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000309    |
# |    value_loss           | 8.1e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | -53          |
# | time/                   |              |
# |    fps                  | 679          |
# |    iterations           | 37           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0037631448 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.0199       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.86e+03     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0019      |
# |    value_loss           | 8.33e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | -53         |
# | time/                   |             |
# |    fps                  | 679         |
# |    iterations           | 38          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.004804154 |
# |    clip_fraction        | 0.00254     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.00496    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.81e+03    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.000579   |
# |    value_loss           | 1.07e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | -32.4        |
# | time/                   |              |
# |    fps                  | 679          |
# |    iterations           | 39           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0043600313 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.943       |
# |    explained_variance   | 0.0242       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.58e+03     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00156     |
# |    value_loss           | 1.54e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | -96.2        |
# | time/                   |              |
# |    fps                  | 679          |
# |    iterations           | 40           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0049607363 |
# |    clip_fraction        | 0.0042       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.949       |
# |    explained_variance   | 0.0872       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.56e+03     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000868    |
# |    value_loss           | 6.43e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | -96.2        |
# | time/                   |              |
# |    fps                  | 678          |
# |    iterations           | 41           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0027095557 |
# |    clip_fraction        | 0.00806      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.907       |
# |    explained_variance   | 0.0366       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.26e+03     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 1.39e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | -75          |
# | time/                   |              |
# |    fps                  | 678          |
# |    iterations           | 42           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0069840946 |
# |    clip_fraction        | 0.00889      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.933       |
# |    explained_variance   | -0.00937     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.76e+03     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -2.73e-05    |
# |    value_loss           | 1.07e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | -75          |
# | time/                   |              |
# |    fps                  | 678          |
# |    iterations           | 43           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0011503149 |
# |    clip_fraction        | 0.054        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.968       |
# |    explained_variance   | -0.0794      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.24e+03     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 0.00107      |
# |    value_loss           | 4.61e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | -17         |
# | time/                   |             |
# |    fps                  | 678         |
# |    iterations           | 44          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.007436143 |
# |    clip_fraction        | 0.0482      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.948      |
# |    explained_variance   | 0.00211     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.99e+03    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00356    |
# |    value_loss           | 1.13e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | -17          |
# | time/                   |              |
# |    fps                  | 678          |
# |    iterations           | 45           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0029339264 |
# |    clip_fraction        | 0.00806      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.941       |
# |    explained_variance   | -0.00685     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3e+03        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 7.41e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | 10.6        |
# | time/                   |             |
# |    fps                  | 677         |
# |    iterations           | 46          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.007832107 |
# |    clip_fraction        | 0.0309      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.974      |
# |    explained_variance   | 0.0021      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.55e+03    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00104    |
# |    value_loss           | 6.84e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | 33.3         |
# | time/                   |              |
# |    fps                  | 677          |
# |    iterations           | 47           |
# |    time_elapsed         | 142          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0068262015 |
# |    clip_fraction        | 0.0456       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.957       |
# |    explained_variance   | 0.0221       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.59e+03     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 9.49e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.56e+03   |
# |    ep_rew_mean          | 33.3       |
# | time/                   |            |
# |    fps                  | 677        |
# |    iterations           | 48         |
# |    time_elapsed         | 145        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.00654109 |
# |    clip_fraction        | 0.0335     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.977     |
# |    explained_variance   | 0.0465     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.45e+03   |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.00172   |
# |    value_loss           | 6.92e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | 75           |
# | time/                   |              |
# |    fps                  | 677          |
# |    iterations           | 49           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0007372645 |
# |    clip_fraction        | 0.00132      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.968       |
# |    explained_variance   | -0.00695     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.17e+03     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 0.000142     |
# |    value_loss           | 1.17e+04     |
# ------------------------------------------

# %% [markdown]
# ## Testing the Trained PPO Agent
#
# This cell focuses on loading and testing the trained PPO agent within the trading environment to evaluate its performance.
#
# **Steps:**
#
# 1. **Load Trained Agent:**
#    - `model = PPO.load("ppo_trading_agent")`: Loads the previously trained PPO agent from the file "ppo_trading_agent".
#
# 2. **Test Environment Setup:**
#    - `obs = env.reset()`: Resets the trading environment to its initial state, preparing it for a new trading episode.
#    - `done = False`: Initializes a flag variable `done` to `False`, indicating that the trading episode is not yet finished.
#
# 3. **Trading Loop:**
#    - `while not done:`: Enters a loop that continues as long as the trading episode is not finished (i.e., `done` is `False`).
#      - `action, _states = model.predict(obs)`: Uses the loaded PPO agent to predict the best action to take based on the current observation (`obs`) of the environment.
#      - `obs, reward, done, _ = env.step(action)`: Executes the predicted action in the environment, updating the environment's state and receiving feedback in the form of a new observation (`obs`), a reward signal (`reward`), a done flag (`done`) indicating whether the episode is finished, and any additional information.
#      - `env.render()`: Displays information about the environment's current state, such as the agent's balance and position.
#
# **Summary:**
#
# This cell loads a trained PPO agent, sets up a trading environment, and runs a trading simulation using the agent's learned policy. It continuously observes the environment, predicts the best actions to take, executes those actions, and receives feedback. The `env.render()` function provides insights into the agent's performance during the simulation, such as its trading decisions and the resulting changes in its balance. This testing process helps evaluate the effectiveness of the trained agent in a simulated trading scenario.

# %%
# Load trained agent
model = PPO.load("ppo_trading_agent")

# Test environment
obs, _ = env.reset()
done = False

while not done:
    action, _states = model.predict(obs)
    obs, reward, done, _, _ = env.step(action)
    env.render()
# Out:
# Step: 1, Balance: 10000.00, Position: 1
# Step: 2, Balance: 10000.00, Position: 1
# Step: 3, Balance: 10000.00, Position: 1
# Step: 4, Balance: 10000.00, Position: 1
# Step: 5, Balance: 10050.00, Position: 0
# Step: 6, Balance: 10050.00, Position: 1
# Step: 7, Balance: 10050.00, Position: 1
# Step: 8, Balance: 10050.00, Position: 1
# Step: 9, Balance: 10050.00, Position: 1
# Step: 10, Balance: 10050.00, Position: 1
# Step: 11, Balance: 10050.00, Position: 1
# Step: 12, Balance: 10050.00, Position: 1
# Step: 13, Balance: 10050.00, Position: 1
# Step: 14, Balance: 10050.00, Position: 1
# Step: 15, Balance: 10050.00, Position: 1
# Step: 16, Balance: 10050.00, Position: 1
# Step: 17, Balance: 10050.00, Position: 1
# Step: 18, Balance: 10050.00, Position: 1
# Step: 19, Balance: 10050.00, Position: 1
# Step: 20, Balance: 10050.00, Position: 1
# Step: 21, Balance: 10050.00, Position: 1
# Step: 22, Balance: 10050.00, Position: 1
# Step: 23, Balance: 10087.50, Position: 0
# Step: 24, Balance: 10087.50, Position: -1
# Step: 25, Balance: 10087.50, Position: -1
# Step: 26, Balance: 10000.00, Position: 0
# Step: 27, Balance: 10000.00, Position: 1
# Step: 28, Balance: 10000.00, Position: 1
# Step: 29, Balance: 10000.00, Position: 1
# Step: 30, Balance: 10000.00, Position: 1
# Step: 31, Balance: 10000.00, Position: 1
# Step: 32, Balance: 10000.00, Position: 1
# Step: 33, Balance: 10000.00, Position: 1
# Step: 34, Balance: 10062.50, Position: 0
# Step: 35, Balance: 10062.50, Position: 1
# Step: 36, Balance: 10062.50, Position: 1
# Step: 37, Balance: 10062.50, Position: 1
# Step: 38, Balance: 10062.50, Position: 1
# Step: 39, Balance: 10062.50, Position: 1
# Step: 40, Balance: 10062.50, Position: 1
# Step: 41, Balance: 10062.50, Position: 1
# Step: 42, Balance: 10062.50, Position: 1
# Step: 43, Balance: 10062.50, Position: 1
# Step: 44, Balance: 10062.50, Position: 1
# Step: 45, Balance: 10062.50, Position: 1
# Step: 46, Balance: 10062.50, Position: 1
# Step: 47, Balance: 10062.50, Position: 1
# Step: 48, Balance: 10062.50, Position: 1
# Step: 49, Balance: 10062.50, Position: 1
# Step: 50, Balance: 10062.50, Position: 1
# Step: 51, Balance: 10062.50, Position: 1
# Step: 52, Balance: 10062.50, Position: 1
# Step: 53, Balance: 10062.50, Position: 1
# Step: 54, Balance: 10062.50, Position: 1
# Step: 55, Balance: 10112.50, Position: 0
# Step: 56, Balance: 10112.50, Position: 0
# Step: 57, Balance: 10112.50, Position: 0
# Step: 58, Balance: 10112.50, Position: 1
# Step: 59, Balance: 10112.50, Position: 1
# Step: 60, Balance: 10112.50, Position: 1
# Step: 61, Balance: 10112.50, Position: 1
# Step: 62, Balance: 10137.50, Position: 0
# Step: 63, Balance: 10137.50, Position: 0
# Step: 64, Balance: 10137.50, Position: 0
# Step: 65, Balance: 10137.50, Position: 1
# Step: 66, Balance: 10137.50, Position: 1
# Step: 67, Balance: 10137.50, Position: 1
# Step: 68, Balance: 10137.50, Position: 1
# Step: 69, Balance: 10137.50, Position: 1
# Step: 70, Balance: 10137.50, Position: 1
# Step: 71, Balance: 10137.50, Position: 1
# Step: 72, Balance: 10137.50, Position: 1
# Step: 73, Balance: 10137.50, Position: 1
# Step: 74, Balance: 10137.50, Position: 1
# Step: 75, Balance: 10137.50, Position: 1
# Step: 76, Balance: 10137.50, Position: 1
# Step: 77, Balance: 10137.50, Position: 1
# Step: 78, Balance: 10137.50, Position: 1
# Step: 79, Balance: 10137.50, Position: 1
# Step: 80, Balance: 10137.50, Position: 1
# Step: 81, Balance: 10137.50, Position: 1
# Step: 82, Balance: 10137.50, Position: 1
# Step: 83, Balance: 10137.50, Position: 1
# Step: 84, Balance: 10137.50, Position: 1
# Step: 85, Balance: 10137.50, Position: 1
# Step: 86, Balance: 10137.50, Position: 1
# Step: 87, Balance: 10137.50, Position: 0
# Step: 88, Balance: 10137.50, Position: 1
# Step: 89, Balance: 10137.50, Position: 1
# Step: 90, Balance: 10137.50, Position: 1
# Step: 91, Balance: 10137.50, Position: 1
# Step: 92, Balance: 10137.50, Position: 1
# Step: 93, Balance: 10137.50, Position: 1
# Step: 94, Balance: 10137.50, Position: 1
# Step: 95, Balance: 10137.50, Position: 1
# Step: 96, Balance: 10137.50, Position: 1
# Step: 97, Balance: 10137.50, Position: 1
# Step: 98, Balance: 10137.50, Position: 1
# Step: 99, Balance: 10137.50, Position: 1
# Step: 100, Balance: 10137.50, Position: 1
# Step: 101, Balance: 10137.50, Position: 1
# Step: 102, Balance: 10212.50, Position: 0
# Step: 103, Balance: 10212.50, Position: -1
# Step: 104, Balance: 10212.50, Position: -1
# Step: 105, Balance: 10300.00, Position: 0
# Step: 106, Balance: 10300.00, Position: 1
# Step: 107, Balance: 10300.00, Position: 1
# Step: 108, Balance: 10300.00, Position: 1
# Step: 109, Balance: 10300.00, Position: 1
# Step: 110, Balance: 10300.00, Position: 1
# Step: 111, Balance: 10300.00, Position: 1
# Step: 112, Balance: 10300.00, Position: 1
# Step: 113, Balance: 10300.00, Position: 1
# Step: 114, Balance: 10300.00, Position: 1
# Step: 115, Balance: 10300.00, Position: 1
# Step: 116, Balance: 10300.00, Position: 1
# Step: 117, Balance: 10425.00, Position: 0
# Step: 118, Balance: 10425.00, Position: 1
# Step: 119, Balance: 10425.00, Position: 1
# Step: 120, Balance: 10425.00, Position: 1
# Step: 121, Balance: 10425.00, Position: 1
# Step: 122, Balance: 10425.00, Position: 1
# Step: 123, Balance: 10425.00, Position: 1
# Step: 124, Balance: 10425.00, Position: 1
# Step: 125, Balance: 10425.00, Position: 1
# Step: 126, Balance: 10425.00, Position: 1
# Step: 127, Balance: 10425.00, Position: 1
# Step: 128, Balance: 10425.00, Position: 1
# Step: 129, Balance: 10425.00, Position: 1
# Step: 130, Balance: 10425.00, Position: 1
# Step: 131, Balance: 10425.00, Position: 1
# Step: 132, Balance: 10425.00, Position: 1
# Step: 133, Balance: 10425.00, Position: 1
# Step: 134, Balance: 10425.00, Position: 1
# Step: 135, Balance: 10425.00, Position: 1
# Step: 136, Balance: 10425.00, Position: 1
# Step: 137, Balance: 10362.50, Position: 0
# Step: 138, Balance: 10362.50, Position: 1
# Step: 139, Balance: 10362.50, Position: 1
# Step: 140, Balance: 10362.50, Position: 1
# Step: 141, Balance: 10362.50, Position: 1
# Step: 142, Balance: 10362.50, Position: 1
# Step: 143, Balance: 10362.50, Position: 1
# Step: 144, Balance: 10362.50, Position: 1
# Step: 145, Balance: 10412.50, Position: 0
# Step: 146, Balance: 10412.50, Position: 1
# Step: 147, Balance: 10412.50, Position: 1
# Step: 148, Balance: 10412.50, Position: 1
# Step: 149, Balance: 10412.50, Position: 1
# Step: 150, Balance: 10412.50, Position: 1
# Step: 151, Balance: 10412.50, Position: 1
# Step: 152, Balance: 10412.50, Position: 1
# Step: 153, Balance: 10412.50, Position: 1
# Step: 154, Balance: 10412.50, Position: 1
# Step: 155, Balance: 10412.50, Position: 1
# Step: 156, Balance: 10412.50, Position: 1
# Step: 157, Balance: 10412.50, Position: 1
# Step: 158, Balance: 10412.50, Position: 1
# Step: 159, Balance: 10412.50, Position: 1
# Step: 160, Balance: 10387.50, Position: 0
# Step: 161, Balance: 10387.50, Position: 0
# Step: 162, Balance: 10387.50, Position: -1
# Step: 163, Balance: 10350.00, Position: 0
# Step: 164, Balance: 10350.00, Position: 0
# Step: 165, Balance: 10350.00, Position: 1
# Step: 166, Balance: 10350.00, Position: 1
# Step: 167, Balance: 10350.00, Position: 1
# Step: 168, Balance: 10350.00, Position: 1
# Step: 169, Balance: 10350.00, Position: 1
# Step: 170, Balance: 10350.00, Position: 1
# Step: 171, Balance: 10350.00, Position: 1
# Step: 172, Balance: 10350.00, Position: 1
# Step: 173, Balance: 10350.00, Position: 1
# Step: 174, Balance: 10350.00, Position: 1
# Step: 175, Balance: 10350.00, Position: 1
# Step: 176, Balance: 10462.50, Position: 0
# Step: 177, Balance: 10462.50, Position: 1
# Step: 178, Balance: 10462.50, Position: 1
# Step: 179, Balance: 10562.50, Position: 0
# Step: 180, Balance: 10562.50, Position: 1
# Step: 181, Balance: 10562.50, Position: 1
# Step: 182, Balance: 10562.50, Position: 1
# Step: 183, Balance: 10562.50, Position: 1
# Step: 184, Balance: 10562.50, Position: 1
# Step: 185, Balance: 10437.50, Position: 0
# Step: 186, Balance: 10437.50, Position: 1
# Step: 187, Balance: 10437.50, Position: 1
# Step: 188, Balance: 10437.50, Position: 1
# Step: 189, Balance: 10437.50, Position: 1
# Step: 190, Balance: 10437.50, Position: 1
# Step: 191, Balance: 10437.50, Position: 1
# Step: 192, Balance: 10437.50, Position: 1
# Step: 193, Balance: 10437.50, Position: 1
# Step: 194, Balance: 10437.50, Position: 1
# Step: 195, Balance: 10437.50, Position: 1
# Step: 196, Balance: 10437.50, Position: 1
# Step: 197, Balance: 10437.50, Position: 1
# Step: 198, Balance: 10437.50, Position: 1
# Step: 199, Balance: 10437.50, Position: 0
# Step: 200, Balance: 10437.50, Position: 0
# Step: 201, Balance: 10437.50, Position: 0
# Step: 202, Balance: 10437.50, Position: -1
# Step: 203, Balance: 10437.50, Position: -1
# Step: 204, Balance: 10425.00, Position: 0
# Step: 205, Balance: 10425.00, Position: 0
# Step: 206, Balance: 10425.00, Position: 0
# Step: 207, Balance: 10425.00, Position: 1
# Step: 208, Balance: 10425.00, Position: 1
# Step: 209, Balance: 10425.00, Position: 1
# Step: 210, Balance: 10425.00, Position: 1
# Step: 211, Balance: 10425.00, Position: 1
# Step: 212, Balance: 10425.00, Position: 1
# Step: 213, Balance: 10425.00, Position: 1
# Step: 214, Balance: 10425.00, Position: 1
# Step: 215, Balance: 10425.00, Position: 1
# Step: 216, Balance: 10425.00, Position: 1
# Step: 217, Balance: 10425.00, Position: 1
# Step: 218, Balance: 10425.00, Position: 1
# Step: 219, Balance: 10475.00, Position: 0
# Step: 220, Balance: 10475.00, Position: 0
# Step: 221, Balance: 10475.00, Position: 1
# Step: 222, Balance: 10475.00, Position: 1
# Step: 223, Balance: 10475.00, Position: 1
# Step: 224, Balance: 10475.00, Position: 1
# Step: 225, Balance: 10475.00, Position: 1
# Step: 226, Balance: 10687.50, Position: 0
# Step: 227, Balance: 10687.50, Position: 1
# Step: 228, Balance: 10687.50, Position: 1
# Step: 229, Balance: 10687.50, Position: 1
# Step: 230, Balance: 10687.50, Position: 1
# Step: 231, Balance: 10812.50, Position: 0
# Step: 232, Balance: 10812.50, Position: -1
# Step: 233, Balance: 10762.50, Position: 0
# Step: 234, Balance: 10762.50, Position: 1
# Step: 235, Balance: 10762.50, Position: 1
# Step: 236, Balance: 10762.50, Position: 1
# Step: 237, Balance: 10762.50, Position: 1
# Step: 238, Balance: 10762.50, Position: 1
# Step: 239, Balance: 10762.50, Position: 1
# Step: 240, Balance: 10762.50, Position: 1
# Step: 241, Balance: 10762.50, Position: 1
# Step: 242, Balance: 10812.50, Position: 0
# Step: 243, Balance: 10812.50, Position: 1
# Step: 244, Balance: 10812.50, Position: 1
# Step: 245, Balance: 10812.50, Position: 1
# Step: 246, Balance: 10812.50, Position: 1
# Step: 247, Balance: 10850.00, Position: 0
# Step: 248, Balance: 10850.00, Position: -1
# Step: 249, Balance: 10850.00, Position: 0
# Step: 250, Balance: 10850.00, Position: 0
# Step: 251, Balance: 10850.00, Position: -1
# Step: 252, Balance: 10850.00, Position: -1
# Step: 253, Balance: 10812.50, Position: 0
# Step: 254, Balance: 10812.50, Position: 1
# Step: 255, Balance: 10812.50, Position: 1
# Step: 256, Balance: 10812.50, Position: 1
# Step: 257, Balance: 10812.50, Position: 1
# Step: 258, Balance: 10812.50, Position: 1
# Step: 259, Balance: 10725.00, Position: 0
# Step: 260, Balance: 10725.00, Position: 1
# Step: 261, Balance: 10725.00, Position: 1
# Step: 262, Balance: 10762.50, Position: 0
# Step: 263, Balance: 10762.50, Position: 1
# Step: 264, Balance: 10762.50, Position: 1
# Step: 265, Balance: 10762.50, Position: 1
# Step: 266, Balance: 10762.50, Position: 1
# Step: 267, Balance: 10762.50, Position: 1
# Step: 268, Balance: 10762.50, Position: 1
# Step: 269, Balance: 10762.50, Position: 1
# Step: 270, Balance: 10762.50, Position: 1
# Step: 271, Balance: 10762.50, Position: 1
# Step: 272, Balance: 10762.50, Position: 1
# Step: 273, Balance: 10762.50, Position: 1
# Step: 274, Balance: 10762.50, Position: 1
# Step: 275, Balance: 10762.50, Position: 1
# Step: 276, Balance: 10762.50, Position: 1
# Step: 277, Balance: 10762.50, Position: 1
# Step: 278, Balance: 10762.50, Position: 1
# Step: 279, Balance: 10762.50, Position: 1
# Step: 280, Balance: 10775.00, Position: 0
# Step: 281, Balance: 10775.00, Position: 0
# Step: 282, Balance: 10775.00, Position: 1
# Step: 283, Balance: 10775.00, Position: 1
# Step: 284, Balance: 10775.00, Position: 1
# Step: 285, Balance: 10775.00, Position: 1
# Step: 286, Balance: 10775.00, Position: 1
# Step: 287, Balance: 10775.00, Position: 1
# Step: 288, Balance: 10775.00, Position: 1
# Step: 289, Balance: 10775.00, Position: 1
# Step: 290, Balance: 10775.00, Position: 1
# Step: 291, Balance: 10775.00, Position: 1
# Step: 292, Balance: 10775.00, Position: 1
# Step: 293, Balance: 10775.00, Position: 1
# Step: 294, Balance: 10775.00, Position: 1
# Step: 295, Balance: 10837.50, Position: 0
# Step: 296, Balance: 10837.50, Position: 0
# Step: 297, Balance: 10837.50, Position: 1
# Step: 298, Balance: 10837.50, Position: 1
# Step: 299, Balance: 10837.50, Position: 1
# Step: 300, Balance: 10837.50, Position: 1
# Step: 301, Balance: 10837.50, Position: 1
# Step: 302, Balance: 10837.50, Position: 1
# Step: 303, Balance: 10837.50, Position: 1
# Step: 304, Balance: 10837.50, Position: 1
# Step: 305, Balance: 10837.50, Position: 1
# Step: 306, Balance: 10837.50, Position: 1
# Step: 307, Balance: 10837.50, Position: 1
# Step: 308, Balance: 10837.50, Position: 1
# Step: 309, Balance: 10837.50, Position: 1
# Step: 310, Balance: 10837.50, Position: 1
# Step: 311, Balance: 10837.50, Position: 1
# Step: 312, Balance: 10837.50, Position: 1
# Step: 313, Balance: 10837.50, Position: 1
# Step: 314, Balance: 10837.50, Position: 1
# Step: 315, Balance: 10837.50, Position: 1
# Step: 316, Balance: 10837.50, Position: 1
# Step: 317, Balance: 10887.50, Position: 0
# Step: 318, Balance: 10887.50, Position: 1
# Step: 319, Balance: 10875.00, Position: 0
# Step: 320, Balance: 10875.00, Position: 1
# Step: 321, Balance: 10875.00, Position: 1
# Step: 322, Balance: 10950.00, Position: 0
# Step: 323, Balance: 10950.00, Position: 0
# Step: 324, Balance: 10950.00, Position: 0
# Step: 325, Balance: 10950.00, Position: 1
# Step: 326, Balance: 10950.00, Position: 1
# Step: 327, Balance: 10975.00, Position: 0
# Step: 328, Balance: 10975.00, Position: 0
# Step: 329, Balance: 10975.00, Position: 1
# Step: 330, Balance: 10975.00, Position: 1
# Step: 331, Balance: 10975.00, Position: 1
# Step: 332, Balance: 10975.00, Position: 1
# Step: 333, Balance: 10975.00, Position: 1
# Step: 334, Balance: 10975.00, Position: 1
# Step: 335, Balance: 10962.50, Position: 0
# Step: 336, Balance: 10962.50, Position: 0
# Step: 337, Balance: 10962.50, Position: 0
# Step: 338, Balance: 10962.50, Position: 1
# Step: 339, Balance: 10962.50, Position: 1
# Step: 340, Balance: 10962.50, Position: 1
# Step: 341, Balance: 10962.50, Position: 1
# Step: 342, Balance: 10962.50, Position: 1
# Step: 343, Balance: 10962.50, Position: 1
# Step: 344, Balance: 10962.50, Position: 1
# Step: 345, Balance: 10962.50, Position: 1
# Step: 346, Balance: 10962.50, Position: 1
# Step: 347, Balance: 10962.50, Position: 1
# Step: 348, Balance: 10962.50, Position: 1
# Step: 349, Balance: 10962.50, Position: 1
# Step: 350, Balance: 10962.50, Position: 1
# Step: 351, Balance: 10962.50, Position: 1
# Step: 352, Balance: 11012.50, Position: 0
# Step: 353, Balance: 11012.50, Position: 1
# Step: 354, Balance: 11012.50, Position: 1
# Step: 355, Balance: 11012.50, Position: 1
# Step: 356, Balance: 10975.00, Position: 0
# Step: 357, Balance: 10975.00, Position: 0
# Step: 358, Balance: 10975.00, Position: 0
# Step: 359, Balance: 10975.00, Position: 1
# Step: 360, Balance: 10975.00, Position: 1
# Step: 361, Balance: 10975.00, Position: 1
# Step: 362, Balance: 10912.50, Position: 0
# Step: 363, Balance: 10912.50, Position: 1
# Step: 364, Balance: 10912.50, Position: 1
# Step: 365, Balance: 10912.50, Position: 1
# Step: 366, Balance: 10912.50, Position: 1
# Step: 367, Balance: 10912.50, Position: 1
# Step: 368, Balance: 10975.00, Position: 0
# Step: 369, Balance: 10975.00, Position: 1
# Step: 370, Balance: 10975.00, Position: 1
# Step: 371, Balance: 10975.00, Position: 1
# Step: 372, Balance: 10837.50, Position: 0
# Step: 373, Balance: 10837.50, Position: 1
# Step: 374, Balance: 10837.50, Position: 1
# Step: 375, Balance: 10837.50, Position: 1
# Step: 376, Balance: 10837.50, Position: 1
# Step: 377, Balance: 10837.50, Position: 1
# Step: 378, Balance: 10837.50, Position: 1
# Step: 379, Balance: 10837.50, Position: 1
# Step: 380, Balance: 10837.50, Position: 1
# Step: 381, Balance: 10837.50, Position: 1
# Step: 382, Balance: 10887.50, Position: 0
# Step: 383, Balance: 10887.50, Position: 1
# Step: 384, Balance: 10887.50, Position: 1
# Step: 385, Balance: 10887.50, Position: 1
# Step: 386, Balance: 10887.50, Position: 1
# Step: 387, Balance: 10887.50, Position: 1
# Step: 388, Balance: 10887.50, Position: 1
# Step: 389, Balance: 10887.50, Position: 1
# Step: 390, Balance: 10887.50, Position: 1
# Step: 391, Balance: 10887.50, Position: 1
# Step: 392, Balance: 10887.50, Position: 1
# Step: 393, Balance: 10887.50, Position: 1
# Step: 394, Balance: 10887.50, Position: 1
# Step: 395, Balance: 10887.50, Position: 1
# Step: 396, Balance: 10850.00, Position: 0
# Step: 397, Balance: 10850.00, Position: 1
# Step: 398, Balance: 10850.00, Position: 1
# Step: 399, Balance: 10850.00, Position: 1
# Step: 400, Balance: 10850.00, Position: 1
# Step: 401, Balance: 10850.00, Position: 1
# Step: 402, Balance: 10850.00, Position: 1
# Step: 403, Balance: 10850.00, Position: 1
# Step: 404, Balance: 10850.00, Position: 1
# Step: 405, Balance: 10850.00, Position: 1
# Step: 406, Balance: 10850.00, Position: 1
# Step: 407, Balance: 10850.00, Position: 1
# Step: 408, Balance: 10850.00, Position: 1
# Step: 409, Balance: 10850.00, Position: 1
# Step: 410, Balance: 10850.00, Position: 1
# Step: 411, Balance: 10850.00, Position: 1
# Step: 412, Balance: 10850.00, Position: 1
# Step: 413, Balance: 10850.00, Position: 1
# Step: 414, Balance: 10850.00, Position: 1
# Step: 415, Balance: 10850.00, Position: 1
# Step: 416, Balance: 10850.00, Position: 1
# Step: 417, Balance: 10850.00, Position: 1
# Step: 418, Balance: 10900.00, Position: 0
# Step: 419, Balance: 10900.00, Position: 0
# Step: 420, Balance: 10900.00, Position: 0
# Step: 421, Balance: 10900.00, Position: 1
# Step: 422, Balance: 10900.00, Position: 1
# Step: 423, Balance: 10900.00, Position: 1
# Step: 424, Balance: 10900.00, Position: 1
# Step: 425, Balance: 10900.00, Position: 1
# Step: 426, Balance: 10900.00, Position: 1
# Step: 427, Balance: 10675.00, Position: 0
# Step: 428, Balance: 10675.00, Position: 1
# Step: 429, Balance: 10675.00, Position: 1
# Step: 430, Balance: 10675.00, Position: 1
# Step: 431, Balance: 10675.00, Position: 1
# Step: 432, Balance: 10825.00, Position: 0
# Step: 433, Balance: 10825.00, Position: 1
# Step: 434, Balance: 10825.00, Position: 1
# Step: 435, Balance: 10825.00, Position: 1
# Step: 436, Balance: 10825.00, Position: 1
# Step: 437, Balance: 10825.00, Position: 1
# Step: 438, Balance: 10825.00, Position: 1
# Step: 439, Balance: 10825.00, Position: 1
# Step: 440, Balance: 10825.00, Position: 1
# Step: 441, Balance: 10825.00, Position: 1
# Step: 442, Balance: 10825.00, Position: 1
# Step: 443, Balance: 10825.00, Position: 1
# Step: 444, Balance: 10825.00, Position: 1
# Step: 445, Balance: 10825.00, Position: 1
# Step: 446, Balance: 10825.00, Position: 0
# Step: 447, Balance: 10825.00, Position: -1
# Step: 448, Balance: 10825.00, Position: -1
# Step: 449, Balance: 10825.00, Position: -1
# Step: 450, Balance: 11062.50, Position: 0
# Step: 451, Balance: 11062.50, Position: 1
# Step: 452, Balance: 11062.50, Position: 1
# Step: 453, Balance: 11062.50, Position: 1
# Step: 454, Balance: 11062.50, Position: 1
# Step: 455, Balance: 11062.50, Position: 1
# Step: 456, Balance: 11062.50, Position: 1
# Step: 457, Balance: 11062.50, Position: 1
# Step: 458, Balance: 11062.50, Position: 1
# Step: 459, Balance: 11062.50, Position: 1
# Step: 460, Balance: 11300.00, Position: 0
# Step: 461, Balance: 11300.00, Position: 1
# Step: 462, Balance: 11300.00, Position: 1
# Step: 463, Balance: 11325.00, Position: 0
# Step: 464, Balance: 11325.00, Position: 0
# Step: 465, Balance: 11325.00, Position: 0
# Step: 466, Balance: 11325.00, Position: 1
# Step: 467, Balance: 11325.00, Position: 1
# Step: 468, Balance: 11325.00, Position: 1
# Step: 469, Balance: 11325.00, Position: 1
# Step: 470, Balance: 11325.00, Position: 1
# Step: 471, Balance: 11325.00, Position: 1
# Step: 472, Balance: 11325.00, Position: 1
# Step: 473, Balance: 11325.00, Position: 1
# Step: 474, Balance: 11325.00, Position: 1
# Step: 475, Balance: 11325.00, Position: 1
# Step: 476, Balance: 11325.00, Position: 1
# Step: 477, Balance: 11325.00, Position: 1
# Step: 478, Balance: 11325.00, Position: 1
# Step: 479, Balance: 11325.00, Position: 1
# Step: 480, Balance: 11325.00, Position: 1
# Step: 481, Balance: 11325.00, Position: 1
# Step: 482, Balance: 11300.00, Position: 0
# Step: 483, Balance: 11300.00, Position: -1
# Step: 484, Balance: 11225.00, Position: 0
# Step: 485, Balance: 11225.00, Position: 1
# Step: 486, Balance: 11225.00, Position: 1
# Step: 487, Balance: 11225.00, Position: 1
# Step: 488, Balance: 11225.00, Position: 1
# Step: 489, Balance: 11187.50, Position: 0
# Step: 490, Balance: 11187.50, Position: 1
# Step: 491, Balance: 11187.50, Position: 1
# Step: 492, Balance: 11187.50, Position: 1
# Step: 493, Balance: 11187.50, Position: 1
# Step: 494, Balance: 11187.50, Position: 1
# Step: 495, Balance: 11187.50, Position: 1
# Step: 496, Balance: 11175.00, Position: 0
# Step: 497, Balance: 11175.00, Position: 1
# Step: 498, Balance: 11175.00, Position: 1
# Step: 499, Balance: 11275.00, Position: 0
# Step: 500, Balance: 11275.00, Position: 0
# Step: 501, Balance: 11275.00, Position: 0
# Step: 502, Balance: 11275.00, Position: 1
# Step: 503, Balance: 11287.50, Position: 0
# Step: 504, Balance: 11287.50, Position: 1
# Step: 505, Balance: 11287.50, Position: 1
# Step: 506, Balance: 11287.50, Position: 1
# Step: 507, Balance: 11287.50, Position: 1
# Step: 508, Balance: 11287.50, Position: 1
# Step: 509, Balance: 11287.50, Position: 1
# Step: 510, Balance: 11287.50, Position: 1
# Step: 511, Balance: 11287.50, Position: 1
# Step: 512, Balance: 11287.50, Position: 1
# Step: 513, Balance: 11287.50, Position: 1
# Step: 514, Balance: 11287.50, Position: 1
# Step: 515, Balance: 11287.50, Position: 1
# Step: 516, Balance: 11287.50, Position: 1
# Step: 517, Balance: 11287.50, Position: 1
# Step: 518, Balance: 11287.50, Position: 1
# Step: 519, Balance: 11287.50, Position: 1
# Step: 520, Balance: 11287.50, Position: 1
# Step: 521, Balance: 11287.50, Position: 1
# Step: 522, Balance: 11350.00, Position: 0
# Step: 523, Balance: 11350.00, Position: 0
# Step: 524, Balance: 11350.00, Position: 1
# Step: 525, Balance: 11350.00, Position: 1
# Step: 526, Balance: 11350.00, Position: 1
# Step: 527, Balance: 11350.00, Position: 1
# Step: 528, Balance: 11350.00, Position: 1
# Step: 529, Balance: 11350.00, Position: 1
# Step: 530, Balance: 11350.00, Position: 1
# Step: 531, Balance: 11350.00, Position: 1
# Step: 532, Balance: 11350.00, Position: 1
# Step: 533, Balance: 11350.00, Position: 1
# Step: 534, Balance: 11350.00, Position: 1
# Step: 535, Balance: 11350.00, Position: 1
# Step: 536, Balance: 11350.00, Position: 1
# Step: 537, Balance: 11350.00, Position: 1
# Step: 538, Balance: 11350.00, Position: 1
# Step: 539, Balance: 11350.00, Position: 1
# Step: 540, Balance: 11350.00, Position: 1
# Step: 541, Balance: 11350.00, Position: 1
# Step: 542, Balance: 11350.00, Position: 1
# Step: 543, Balance: 11350.00, Position: 1
# Step: 544, Balance: 11350.00, Position: 1
# Step: 545, Balance: 11350.00, Position: 1
# Step: 546, Balance: 11350.00, Position: 1
# Step: 547, Balance: 11350.00, Position: 1
# Step: 548, Balance: 11350.00, Position: 1
# Step: 549, Balance: 11350.00, Position: 1
# Step: 550, Balance: 11350.00, Position: 1
# Step: 551, Balance: 11337.50, Position: 0
# Step: 552, Balance: 11337.50, Position: 1
# Step: 553, Balance: 11337.50, Position: 1
# Step: 554, Balance: 11337.50, Position: 1
# Step: 555, Balance: 11337.50, Position: 1
# Step: 556, Balance: 11337.50, Position: 1
# Step: 557, Balance: 11337.50, Position: 1
# Step: 558, Balance: 11337.50, Position: 1
# Step: 559, Balance: 11337.50, Position: 1
# Step: 560, Balance: 11337.50, Position: 1
# Step: 561, Balance: 11337.50, Position: 1
# Step: 562, Balance: 11337.50, Position: 1
# Step: 563, Balance: 11337.50, Position: 1
# Step: 564, Balance: 11337.50, Position: 1
# Step: 565, Balance: 11337.50, Position: 1
# Step: 566, Balance: 11312.50, Position: 0
# Step: 567, Balance: 11312.50, Position: 0
# Step: 568, Balance: 11312.50, Position: 1
# Step: 569, Balance: 11312.50, Position: 1
# Step: 570, Balance: 11312.50, Position: 1
# Step: 571, Balance: 11312.50, Position: 1
# Step: 572, Balance: 11312.50, Position: 1
# Step: 573, Balance: 11312.50, Position: 1
# Step: 574, Balance: 11312.50, Position: 1
# Step: 575, Balance: 11312.50, Position: 1
# Step: 576, Balance: 11312.50, Position: 1
# Step: 577, Balance: 11312.50, Position: 1
# Step: 578, Balance: 11300.00, Position: 0
# Step: 579, Balance: 11300.00, Position: 1
# Step: 580, Balance: 11300.00, Position: 1
# Step: 581, Balance: 11300.00, Position: 1
# Step: 582, Balance: 11300.00, Position: 1
# Step: 583, Balance: 11300.00, Position: 1
# Step: 584, Balance: 11300.00, Position: 1
# Step: 585, Balance: 11300.00, Position: 1
# Step: 586, Balance: 11300.00, Position: 1
# Step: 587, Balance: 11300.00, Position: 1
# Step: 588, Balance: 11300.00, Position: 1
# Step: 589, Balance: 11287.50, Position: 0
# Step: 590, Balance: 11287.50, Position: 0
# Step: 591, Balance: 11287.50, Position: 1
# Step: 592, Balance: 11287.50, Position: 1
# Step: 593, Balance: 11287.50, Position: 1
# Step: 594, Balance: 11287.50, Position: 1
# Step: 595, Balance: 11287.50, Position: 1
# Step: 596, Balance: 11287.50, Position: 1
# Step: 597, Balance: 11287.50, Position: 1
# Step: 598, Balance: 11287.50, Position: 1
# Step: 599, Balance: 11287.50, Position: 1
# Step: 600, Balance: 11287.50, Position: 1
# Step: 601, Balance: 11287.50, Position: 1
# Step: 602, Balance: 11287.50, Position: 1
# Step: 603, Balance: 11287.50, Position: 1
# Step: 604, Balance: 11287.50, Position: 1
# Step: 605, Balance: 11287.50, Position: 1
# Step: 606, Balance: 11287.50, Position: 1
# Step: 607, Balance: 11287.50, Position: 1
# Step: 608, Balance: 11287.50, Position: 1
# Step: 609, Balance: 11287.50, Position: 1
# Step: 610, Balance: 11287.50, Position: 1
# Step: 611, Balance: 11287.50, Position: 1
# Step: 612, Balance: 11287.50, Position: 1
# Step: 613, Balance: 11287.50, Position: 1
# Step: 614, Balance: 11287.50, Position: 1
# Step: 615, Balance: 11287.50, Position: 1
# Step: 616, Balance: 11287.50, Position: 1
# Step: 617, Balance: 11287.50, Position: 1
# Step: 618, Balance: 11287.50, Position: 1
# Step: 619, Balance: 11287.50, Position: 1
# Step: 620, Balance: 11287.50, Position: 1
# Step: 621, Balance: 11287.50, Position: 1
# Step: 622, Balance: 11287.50, Position: 1
# Step: 623, Balance: 11275.00, Position: 0
# Step: 624, Balance: 11275.00, Position: 0
# Step: 625, Balance: 11275.00, Position: 0
# Step: 626, Balance: 11275.00, Position: 1
# Step: 627, Balance: 11275.00, Position: 1
# Step: 628, Balance: 11350.00, Position: 0
# Step: 629, Balance: 11350.00, Position: 0
# Step: 630, Balance: 11350.00, Position: 0
# Step: 631, Balance: 11350.00, Position: 1
# Step: 632, Balance: 11350.00, Position: 1
# Step: 633, Balance: 11350.00, Position: 1
# Step: 634, Balance: 11350.00, Position: 1
# Step: 635, Balance: 11350.00, Position: 1
# Step: 636, Balance: 11362.50, Position: 0
# Step: 637, Balance: 11362.50, Position: 0
# Step: 638, Balance: 11362.50, Position: 1
# Step: 639, Balance: 11362.50, Position: 1
# Step: 640, Balance: 11250.00, Position: 0
# Step: 641, Balance: 11250.00, Position: 1
# Step: 642, Balance: 11250.00, Position: 1
# Step: 643, Balance: 11350.00, Position: 0
# Step: 644, Balance: 11350.00, Position: 1
# Step: 645, Balance: 11350.00, Position: 1
# Step: 646, Balance: 11350.00, Position: 1
# Step: 647, Balance: 11350.00, Position: 1
# Step: 648, Balance: 11350.00, Position: 1
# Step: 649, Balance: 11350.00, Position: 1
# Step: 650, Balance: 11350.00, Position: 1
# Step: 651, Balance: 11350.00, Position: 1
# Step: 652, Balance: 11350.00, Position: 1
# Step: 653, Balance: 11350.00, Position: 1
# Step: 654, Balance: 11350.00, Position: 1
# Step: 655, Balance: 11300.00, Position: 0
# Step: 656, Balance: 11300.00, Position: 1
# Step: 657, Balance: 11300.00, Position: 1
# Step: 658, Balance: 11300.00, Position: 1
# Step: 659, Balance: 11300.00, Position: 1
# Step: 660, Balance: 11300.00, Position: 1
# Step: 661, Balance: 11300.00, Position: 1
# Step: 662, Balance: 11300.00, Position: 1
# Step: 663, Balance: 11300.00, Position: 1
# Step: 664, Balance: 11300.00, Position: 1
# Step: 665, Balance: 11300.00, Position: 1
# Step: 666, Balance: 11300.00, Position: 1
# Step: 667, Balance: 11300.00, Position: 1
# Step: 668, Balance: 11300.00, Position: 1
# Step: 669, Balance: 11300.00, Position: 1
# Step: 670, Balance: 11300.00, Position: 1
# Step: 671, Balance: 11300.00, Position: 1
# Step: 672, Balance: 11300.00, Position: 1
# Step: 673, Balance: 11300.00, Position: 1
# Step: 674, Balance: 11300.00, Position: 1
# Step: 675, Balance: 11300.00, Position: 1
# Step: 676, Balance: 11300.00, Position: 1
# Step: 677, Balance: 11300.00, Position: 1
# Step: 678, Balance: 11300.00, Position: 1
# Step: 679, Balance: 11300.00, Position: 1
# Step: 680, Balance: 11300.00, Position: 1
# Step: 681, Balance: 11300.00, Position: 1
# Step: 682, Balance: 11387.50, Position: 0
# Step: 683, Balance: 11387.50, Position: 1
# Step: 684, Balance: 11437.50, Position: 0
# Step: 685, Balance: 11437.50, Position: 0
# Step: 686, Balance: 11437.50, Position: 1
# Step: 687, Balance: 11462.50, Position: 0
# Step: 688, Balance: 11462.50, Position: 1
# Step: 689, Balance: 11462.50, Position: 1
# Step: 690, Balance: 11462.50, Position: 1
# Step: 691, Balance: 11500.00, Position: 0
# Step: 692, Balance: 11500.00, Position: 1
# Step: 693, Balance: 11500.00, Position: 1
# Step: 694, Balance: 11500.00, Position: 1
# Step: 695, Balance: 11500.00, Position: 1
# Step: 696, Balance: 11525.00, Position: 0
# Step: 697, Balance: 11525.00, Position: 1
# Step: 698, Balance: 11525.00, Position: 1
# Step: 699, Balance: 11525.00, Position: 1
# Step: 700, Balance: 11525.00, Position: 1
# Step: 701, Balance: 11525.00, Position: 1
# Step: 702, Balance: 11525.00, Position: 1
# Step: 703, Balance: 11512.50, Position: 0
# Step: 704, Balance: 11512.50, Position: 1
# Step: 705, Balance: 11512.50, Position: 1
# Step: 706, Balance: 11512.50, Position: 1
# Step: 707, Balance: 11512.50, Position: 1
# Step: 708, Balance: 11550.00, Position: 0
# Step: 709, Balance: 11550.00, Position: 0
# Step: 710, Balance: 11550.00, Position: 1
# Step: 711, Balance: 11562.50, Position: 0
# Step: 712, Balance: 11562.50, Position: -1
# Step: 713, Balance: 11550.00, Position: 0
# Step: 714, Balance: 11550.00, Position: 0
# Step: 715, Balance: 11550.00, Position: 1
# Step: 716, Balance: 11550.00, Position: 1
# Step: 717, Balance: 11537.50, Position: 0
# Step: 718, Balance: 11537.50, Position: -1
# Step: 719, Balance: 11537.50, Position: -1
# Step: 720, Balance: 11537.50, Position: -1
# Step: 721, Balance: 11537.50, Position: -1
# Step: 722, Balance: 11537.50, Position: -1
# Step: 723, Balance: 11537.50, Position: -1
# Step: 724, Balance: 11550.00, Position: 0
# Step: 725, Balance: 11550.00, Position: 0
# Step: 726, Balance: 11550.00, Position: 1
# Step: 727, Balance: 11450.00, Position: 0
# Step: 728, Balance: 11450.00, Position: 1
# Step: 729, Balance: 11450.00, Position: 1
# Step: 730, Balance: 11450.00, Position: 1
# Step: 731, Balance: 11450.00, Position: 1
# Step: 732, Balance: 11450.00, Position: 1
# Step: 733, Balance: 11450.00, Position: 1
# Step: 734, Balance: 11450.00, Position: 1
# Step: 735, Balance: 11450.00, Position: 1
# Step: 736, Balance: 11450.00, Position: 1
# Step: 737, Balance: 11475.00, Position: 0
# Step: 738, Balance: 11475.00, Position: 1
# Step: 739, Balance: 11475.00, Position: 1
# Step: 740, Balance: 11475.00, Position: 1
# Step: 741, Balance: 11475.00, Position: 1
# Step: 742, Balance: 11475.00, Position: 1
# Step: 743, Balance: 11475.00, Position: 1
# Step: 744, Balance: 11475.00, Position: 1
# Step: 745, Balance: 11475.00, Position: 1
# Step: 746, Balance: 11475.00, Position: 1
# Step: 747, Balance: 11475.00, Position: 1
# Step: 748, Balance: 11475.00, Position: 1
# Step: 749, Balance: 11475.00, Position: 1
# Step: 750, Balance: 11475.00, Position: 1
# Step: 751, Balance: 11475.00, Position: 1
# Step: 752, Balance: 11475.00, Position: 1
# Step: 753, Balance: 11475.00, Position: 1
# Step: 754, Balance: 11475.00, Position: 1
# Step: 755, Balance: 11475.00, Position: 1
# Step: 756, Balance: 11475.00, Position: 1
# Step: 757, Balance: 11475.00, Position: 1
# Step: 758, Balance: 11475.00, Position: 1
# Step: 759, Balance: 11475.00, Position: 1
# Step: 760, Balance: 11475.00, Position: 1
# Step: 761, Balance: 11475.00, Position: 1
# Step: 762, Balance: 11475.00, Position: 1
# Step: 763, Balance: 11475.00, Position: 1
# Step: 764, Balance: 11475.00, Position: 1
# Step: 765, Balance: 11412.50, Position: 0
# Step: 766, Balance: 11412.50, Position: 1
# Step: 767, Balance: 11437.50, Position: 0
# Step: 768, Balance: 11437.50, Position: 0
# Step: 769, Balance: 11437.50, Position: 0
# Step: 770, Balance: 11437.50, Position: 1
# Step: 771, Balance: 11437.50, Position: 1
# Step: 772, Balance: 11437.50, Position: 1
# Step: 773, Balance: 11437.50, Position: 1
# Step: 774, Balance: 11412.50, Position: 0
# Step: 775, Balance: 11412.50, Position: 0
# Step: 776, Balance: 11412.50, Position: 1
# Step: 777, Balance: 11412.50, Position: 1
# Step: 778, Balance: 11412.50, Position: 1
# Step: 779, Balance: 11412.50, Position: 1
# Step: 780, Balance: 11412.50, Position: 1
# Step: 781, Balance: 11412.50, Position: 1
# Step: 782, Balance: 11412.50, Position: 1
# Step: 783, Balance: 11400.00, Position: 0
# Step: 784, Balance: 11400.00, Position: 1
# Step: 785, Balance: 11400.00, Position: 1
# Step: 786, Balance: 11400.00, Position: 1
# Step: 787, Balance: 11400.00, Position: 1
# Step: 788, Balance: 11400.00, Position: 1
# Step: 789, Balance: 11400.00, Position: 1
# Step: 790, Balance: 11500.00, Position: 0
# Step: 791, Balance: 11500.00, Position: 0
# Step: 792, Balance: 11500.00, Position: 0
# Step: 793, Balance: 11500.00, Position: 0
# Step: 794, Balance: 11500.00, Position: 0
# Step: 795, Balance: 11500.00, Position: 1
# Step: 796, Balance: 11500.00, Position: 1
# Step: 797, Balance: 11500.00, Position: 1
# Step: 798, Balance: 11487.50, Position: 0
# Step: 799, Balance: 11487.50, Position: 1
# Step: 800, Balance: 11487.50, Position: 1
# Step: 801, Balance: 11487.50, Position: 1
# Step: 802, Balance: 11487.50, Position: 1
# Step: 803, Balance: 11487.50, Position: 1
# Step: 804, Balance: 11487.50, Position: 1
# Step: 805, Balance: 11487.50, Position: 1
# Step: 806, Balance: 11487.50, Position: 1
# Step: 807, Balance: 11500.00, Position: 0
# Step: 808, Balance: 11500.00, Position: 1
# Step: 809, Balance: 11500.00, Position: 1
# Step: 810, Balance: 11500.00, Position: 1
# Step: 811, Balance: 11500.00, Position: 1
# Step: 812, Balance: 11500.00, Position: 1
# Step: 813, Balance: 11500.00, Position: 1
# Step: 814, Balance: 11500.00, Position: 1
# Step: 815, Balance: 11500.00, Position: 1
# Step: 816, Balance: 11525.00, Position: 0
# Step: 817, Balance: 11525.00, Position: 0
# Step: 818, Balance: 11525.00, Position: 0
# Step: 819, Balance: 11525.00, Position: 1
# Step: 820, Balance: 11525.00, Position: 1
# Step: 821, Balance: 11525.00, Position: 1
# Step: 822, Balance: 11525.00, Position: 1
# Step: 823, Balance: 11525.00, Position: 1
# Step: 824, Balance: 11525.00, Position: 1
# Step: 825, Balance: 11500.00, Position: 0
# Step: 826, Balance: 11500.00, Position: 0
# Step: 827, Balance: 11500.00, Position: 1
# Step: 828, Balance: 11500.00, Position: 1
# Step: 829, Balance: 11500.00, Position: 1
# Step: 830, Balance: 11500.00, Position: 1
# Step: 831, Balance: 11500.00, Position: 1
# Step: 832, Balance: 11500.00, Position: 1
# Step: 833, Balance: 11500.00, Position: 1
# Step: 834, Balance: 11500.00, Position: 1
# Step: 835, Balance: 11500.00, Position: 1
# Step: 836, Balance: 11500.00, Position: 1
# Step: 837, Balance: 11462.50, Position: 0
# Step: 838, Balance: 11462.50, Position: 1
# Step: 839, Balance: 11462.50, Position: 1
# Step: 840, Balance: 11462.50, Position: 1
# Step: 841, Balance: 11462.50, Position: 1
# Step: 842, Balance: 11437.50, Position: 0
# Step: 843, Balance: 11437.50, Position: 1
# Step: 844, Balance: 11437.50, Position: 1
# Step: 845, Balance: 11437.50, Position: 1
# Step: 846, Balance: 11437.50, Position: 1
# Step: 847, Balance: 11437.50, Position: 1
# Step: 848, Balance: 11437.50, Position: 1
# Step: 849, Balance: 11437.50, Position: 1
# Step: 850, Balance: 11437.50, Position: 1
# Step: 851, Balance: 11437.50, Position: 1
# Step: 852, Balance: 11437.50, Position: 1
# Step: 853, Balance: 11437.50, Position: 1
# Step: 854, Balance: 11437.50, Position: 1
# Step: 855, Balance: 11437.50, Position: 1
# Step: 856, Balance: 11437.50, Position: 1
# Step: 857, Balance: 11437.50, Position: 1
# Step: 858, Balance: 11437.50, Position: 1
# Step: 859, Balance: 11437.50, Position: 1
# Step: 860, Balance: 11437.50, Position: 1
# Step: 861, Balance: 11437.50, Position: 1
# Step: 862, Balance: 11437.50, Position: 1
# Step: 863, Balance: 11437.50, Position: 1
# Step: 864, Balance: 11437.50, Position: 1
# Step: 865, Balance: 11437.50, Position: 1
# Step: 866, Balance: 11437.50, Position: 1
# Step: 867, Balance: 11437.50, Position: 1
# Step: 868, Balance: 11437.50, Position: 1
# Step: 869, Balance: 11450.00, Position: 0
# Step: 870, Balance: 11450.00, Position: 1
# Step: 871, Balance: 11450.00, Position: 1
# Step: 872, Balance: 11475.00, Position: 0
# Step: 873, Balance: 11475.00, Position: -1
# Step: 874, Balance: 11487.50, Position: 0
# Step: 875, Balance: 11487.50, Position: 1
# Step: 876, Balance: 11487.50, Position: 1
# Step: 877, Balance: 11487.50, Position: 1
# Step: 878, Balance: 11487.50, Position: 1
# Step: 879, Balance: 11450.00, Position: 0
# Step: 880, Balance: 11450.00, Position: 1
# Step: 881, Balance: 11450.00, Position: 1
# Step: 882, Balance: 11425.00, Position: 0
# Step: 883, Balance: 11425.00, Position: -1
# Step: 884, Balance: 11412.50, Position: 0
# Step: 885, Balance: 11412.50, Position: 0
# Step: 886, Balance: 11412.50, Position: 1
# Step: 887, Balance: 11412.50, Position: 1
# Step: 888, Balance: 11412.50, Position: 1
# Step: 889, Balance: 11400.00, Position: 0
# Step: 890, Balance: 11400.00, Position: 1
# Step: 891, Balance: 11400.00, Position: 1
# Step: 892, Balance: 11400.00, Position: 1
# Step: 893, Balance: 11400.00, Position: 1
# Step: 894, Balance: 11400.00, Position: 1
# Step: 895, Balance: 11400.00, Position: 1
# Step: 896, Balance: 11400.00, Position: 1
# Step: 897, Balance: 11400.00, Position: 1
# Step: 898, Balance: 11400.00, Position: 1
# Step: 899, Balance: 11400.00, Position: 1
# Step: 900, Balance: 11400.00, Position: 1
# Step: 901, Balance: 11475.00, Position: 0
# Step: 902, Balance: 11475.00, Position: 0
# Step: 903, Balance: 11475.00, Position: 0
# Step: 904, Balance: 11475.00, Position: 1
# Step: 905, Balance: 11475.00, Position: 1
# Step: 906, Balance: 11475.00, Position: 1
# Step: 907, Balance: 11475.00, Position: 1
# Step: 908, Balance: 11475.00, Position: 1
# Step: 909, Balance: 11462.50, Position: 0
# Step: 910, Balance: 11462.50, Position: 0
# Step: 911, Balance: 11462.50, Position: 1
# Step: 912, Balance: 11462.50, Position: 1
# Step: 913, Balance: 11462.50, Position: 1
# Step: 914, Balance: 11437.50, Position: 0
# Step: 915, Balance: 11437.50, Position: 1
# Step: 916, Balance: 11450.00, Position: 0
# Step: 917, Balance: 11450.00, Position: 0
# Step: 918, Balance: 11450.00, Position: 1
# Step: 919, Balance: 11487.50, Position: 0
# Step: 920, Balance: 11487.50, Position: 0
# Step: 921, Balance: 11487.50, Position: 1
# Step: 922, Balance: 11487.50, Position: 1
# Step: 923, Balance: 11487.50, Position: 1
# Step: 924, Balance: 11487.50, Position: 1
# Step: 925, Balance: 11487.50, Position: 1
# Step: 926, Balance: 11500.00, Position: 0
# Step: 927, Balance: 11500.00, Position: 1
# Step: 928, Balance: 11512.50, Position: 0
# Step: 929, Balance: 11512.50, Position: -1
# Step: 930, Balance: 11512.50, Position: -1
# Step: 931, Balance: 11512.50, Position: -1
# Step: 932, Balance: 11512.50, Position: -1
# Step: 933, Balance: 11512.50, Position: -1
# Step: 934, Balance: 11512.50, Position: -1
# Step: 935, Balance: 11512.50, Position: 0
# Step: 936, Balance: 11512.50, Position: 1
# Step: 937, Balance: 11512.50, Position: 1
# Step: 938, Balance: 11512.50, Position: 1
# Step: 939, Balance: 11512.50, Position: 1
# Step: 940, Balance: 11512.50, Position: 1
# Step: 941, Balance: 11512.50, Position: 1
# Step: 942, Balance: 11512.50, Position: 1
# Step: 943, Balance: 11512.50, Position: 1
# Step: 944, Balance: 11512.50, Position: 1
# Step: 945, Balance: 11537.50, Position: 0
# Step: 946, Balance: 11537.50, Position: 1
# Step: 947, Balance: 11537.50, Position: 1
# Step: 948, Balance: 11537.50, Position: 1
# Step: 949, Balance: 11537.50, Position: 1
# Step: 950, Balance: 11537.50, Position: 1
# Step: 951, Balance: 11537.50, Position: 1
# Step: 952, Balance: 11537.50, Position: 0
# Step: 953, Balance: 11537.50, Position: 0
# Step: 954, Balance: 11537.50, Position: 1
# Step: 955, Balance: 11537.50, Position: 1
# Step: 956, Balance: 11537.50, Position: 1
# Step: 957, Balance: 11537.50, Position: 1
# Step: 958, Balance: 11537.50, Position: 1
# Step: 959, Balance: 11537.50, Position: 1
# Step: 960, Balance: 11537.50, Position: 1
# Step: 961, Balance: 11537.50, Position: 1
# Step: 962, Balance: 11537.50, Position: 1
# Step: 963, Balance: 11537.50, Position: 1
# Step: 964, Balance: 11525.00, Position: 0
# Step: 965, Balance: 11525.00, Position: 0
# Step: 966, Balance: 11525.00, Position: 1
# Step: 967, Balance: 11550.00, Position: 0
# Step: 968, Balance: 11550.00, Position: 1
# Step: 969, Balance: 11550.00, Position: 1
# Step: 970, Balance: 11550.00, Position: 1
# Step: 971, Balance: 11550.00, Position: 1
# Step: 972, Balance: 11550.00, Position: 1
# Step: 973, Balance: 11550.00, Position: 1
# Step: 974, Balance: 11637.50, Position: 0
# Step: 975, Balance: 11637.50, Position: 1
# Step: 976, Balance: 11637.50, Position: 1
# Step: 977, Balance: 11637.50, Position: 1
# Step: 978, Balance: 11637.50, Position: 1
# Step: 979, Balance: 11637.50, Position: 1
# Step: 980, Balance: 11637.50, Position: 1
# Step: 981, Balance: 11637.50, Position: 1
# Step: 982, Balance: 11637.50, Position: 1
# Step: 983, Balance: 11637.50, Position: 1
# Step: 984, Balance: 11637.50, Position: 1
# Step: 985, Balance: 11637.50, Position: 1
# Step: 986, Balance: 11612.50, Position: 0
# Step: 987, Balance: 11612.50, Position: 1
# Step: 988, Balance: 11612.50, Position: 1
# Step: 989, Balance: 11612.50, Position: 1
# Step: 990, Balance: 11612.50, Position: 1
# Step: 991, Balance: 11612.50, Position: 1
# Step: 992, Balance: 11612.50, Position: 1
# Step: 993, Balance: 11612.50, Position: 1
# Step: 994, Balance: 11612.50, Position: 1
# Step: 995, Balance: 11612.50, Position: 1
# Step: 996, Balance: 11612.50, Position: 1
# Step: 997, Balance: 11612.50, Position: 0
# Step: 998, Balance: 11612.50, Position: 1
# Step: 999, Balance: 11612.50, Position: 1
# Step: 1000, Balance: 11612.50, Position: 1
# Step: 1001, Balance: 11625.00, Position: 0
# Step: 1002, Balance: 11625.00, Position: 0
# Step: 1003, Balance: 11625.00, Position: 1
# Step: 1004, Balance: 11625.00, Position: 1
# Step: 1005, Balance: 11625.00, Position: 1
# Step: 1006, Balance: 11625.00, Position: 1
# Step: 1007, Balance: 11625.00, Position: 1
# Step: 1008, Balance: 11625.00, Position: 1
# Step: 1009, Balance: 11662.50, Position: 0
# Step: 1010, Balance: 11662.50, Position: -1
# Step: 1011, Balance: 11712.50, Position: 0
# Step: 1012, Balance: 11712.50, Position: 1
# Step: 1013, Balance: 11712.50, Position: 1
# Step: 1014, Balance: 11712.50, Position: 1
# Step: 1015, Balance: 11712.50, Position: 1
# Step: 1016, Balance: 11712.50, Position: 1
# Step: 1017, Balance: 11712.50, Position: 1
# Step: 1018, Balance: 11700.00, Position: 0
# Step: 1019, Balance: 11700.00, Position: 1
# Step: 1020, Balance: 11700.00, Position: 1
# Step: 1021, Balance: 11675.00, Position: 0
# Step: 1022, Balance: 11675.00, Position: 0
# Step: 1023, Balance: 11675.00, Position: 0
# Step: 1024, Balance: 11675.00, Position: 1
# Step: 1025, Balance: 11675.00, Position: 1
# Step: 1026, Balance: 11675.00, Position: 1
# Step: 1027, Balance: 11675.00, Position: 1
# Step: 1028, Balance: 11675.00, Position: 1
# Step: 1029, Balance: 11675.00, Position: 1
# Step: 1030, Balance: 11675.00, Position: 1
# Step: 1031, Balance: 11675.00, Position: 1
# Step: 1032, Balance: 11675.00, Position: 1
# Step: 1033, Balance: 11675.00, Position: 1
# Step: 1034, Balance: 11675.00, Position: 1
# Step: 1035, Balance: 11675.00, Position: 1
# Step: 1036, Balance: 11675.00, Position: 1
# Step: 1037, Balance: 11675.00, Position: 1
# Step: 1038, Balance: 11700.00, Position: 0
# Step: 1039, Balance: 11700.00, Position: 1
# Step: 1040, Balance: 11700.00, Position: 1
# Step: 1041, Balance: 11700.00, Position: 1
# Step: 1042, Balance: 11700.00, Position: 1
# Step: 1043, Balance: 11700.00, Position: 1
# Step: 1044, Balance: 11700.00, Position: 1
# Step: 1045, Balance: 11700.00, Position: 1
# Step: 1046, Balance: 11700.00, Position: 1
# Step: 1047, Balance: 11700.00, Position: 1
# Step: 1048, Balance: 11700.00, Position: 1
# Step: 1049, Balance: 11750.00, Position: 0
# Step: 1050, Balance: 11750.00, Position: 0
# Step: 1051, Balance: 11750.00, Position: 1
# Step: 1052, Balance: 11750.00, Position: 1
# Step: 1053, Balance: 11750.00, Position: 1
# Step: 1054, Balance: 11750.00, Position: 1
# Step: 1055, Balance: 11737.50, Position: 0
# Step: 1056, Balance: 11737.50, Position: 1
# Step: 1057, Balance: 11775.00, Position: 0
# Step: 1058, Balance: 11775.00, Position: 1
# Step: 1059, Balance: 11775.00, Position: 1
# Step: 1060, Balance: 11775.00, Position: 1
# Step: 1061, Balance: 11775.00, Position: 1
# Step: 1062, Balance: 11775.00, Position: 1
# Step: 1063, Balance: 11850.00, Position: 0
# Step: 1064, Balance: 11850.00, Position: -1
# Step: 1065, Balance: 12000.00, Position: 0
# Step: 1066, Balance: 12000.00, Position: 1
# Step: 1067, Balance: 12000.00, Position: 1
# Step: 1068, Balance: 12150.00, Position: 0
# Step: 1069, Balance: 12150.00, Position: 0
# Step: 1070, Balance: 12150.00, Position: 1
# Step: 1071, Balance: 12150.00, Position: 1
# Step: 1072, Balance: 12250.00, Position: 0
# Step: 1073, Balance: 12250.00, Position: 1
# Step: 1074, Balance: 12250.00, Position: 1
# Step: 1075, Balance: 12250.00, Position: 1
# Step: 1076, Balance: 12325.00, Position: 0
# Step: 1077, Balance: 12325.00, Position: 1
# Step: 1078, Balance: 12250.00, Position: 0
# Step: 1079, Balance: 12250.00, Position: 1
# Step: 1080, Balance: 12175.00, Position: 0
# Step: 1081, Balance: 12175.00, Position: 1
# Step: 1082, Balance: 12175.00, Position: 1
# Step: 1083, Balance: 12175.00, Position: 1
# Step: 1084, Balance: 12175.00, Position: 1
# Step: 1085, Balance: 12175.00, Position: 1
# Step: 1086, Balance: 12175.00, Position: 1
# Step: 1087, Balance: 12175.00, Position: 1
# Step: 1088, Balance: 12175.00, Position: 1
# Step: 1089, Balance: 12175.00, Position: 1
# Step: 1090, Balance: 12175.00, Position: 1
# Step: 1091, Balance: 12175.00, Position: 1
# Step: 1092, Balance: 12175.00, Position: 1
# Step: 1093, Balance: 12175.00, Position: 1
# Step: 1094, Balance: 12062.50, Position: 0
# Step: 1095, Balance: 12062.50, Position: 1
# Step: 1096, Balance: 12062.50, Position: 1
# Step: 1097, Balance: 12062.50, Position: 1
# Step: 1098, Balance: 12087.50, Position: 0
# Step: 1099, Balance: 12087.50, Position: 1
# Step: 1100, Balance: 12087.50, Position: 1
# Step: 1101, Balance: 12087.50, Position: 1
# Step: 1102, Balance: 12087.50, Position: 1
# Step: 1103, Balance: 12225.00, Position: 0
# Step: 1104, Balance: 12225.00, Position: 0
# Step: 1105, Balance: 12225.00, Position: 1
# Step: 1106, Balance: 12100.00, Position: 0
# Step: 1107, Balance: 12100.00, Position: 1
# Step: 1108, Balance: 12100.00, Position: 1
# Step: 1109, Balance: 12100.00, Position: 1
# Step: 1110, Balance: 12100.00, Position: 1
# Step: 1111, Balance: 12100.00, Position: 1
# Step: 1112, Balance: 12100.00, Position: 1
# Step: 1113, Balance: 12100.00, Position: 1
# Step: 1114, Balance: 12100.00, Position: 1
# Step: 1115, Balance: 12100.00, Position: 1
# Step: 1116, Balance: 12100.00, Position: 1
# Step: 1117, Balance: 12100.00, Position: 1
# Step: 1118, Balance: 12262.50, Position: 0
# Step: 1119, Balance: 12262.50, Position: 0
# Step: 1120, Balance: 12262.50, Position: 1
# Step: 1121, Balance: 12262.50, Position: 1
# Step: 1122, Balance: 12200.00, Position: 0
# Step: 1123, Balance: 12200.00, Position: -1
# Step: 1124, Balance: 12350.00, Position: 0
# Step: 1125, Balance: 12350.00, Position: 1
# Step: 1126, Balance: 12350.00, Position: 1
# Step: 1127, Balance: 12350.00, Position: 1
# Step: 1128, Balance: 12350.00, Position: 1
# Step: 1129, Balance: 12350.00, Position: 1
# Step: 1130, Balance: 12350.00, Position: 1
# Step: 1131, Balance: 12350.00, Position: 1
# Step: 1132, Balance: 12350.00, Position: 1
# Step: 1133, Balance: 12350.00, Position: 1
# Step: 1134, Balance: 12350.00, Position: 1
# Step: 1135, Balance: 12350.00, Position: 1
# Step: 1136, Balance: 12350.00, Position: 1
# Step: 1137, Balance: 12375.00, Position: 0
# Step: 1138, Balance: 12375.00, Position: 1
# Step: 1139, Balance: 12375.00, Position: 1
# Step: 1140, Balance: 12375.00, Position: 1
# Step: 1141, Balance: 12375.00, Position: 1
# ...
# Step: 3190, Balance: 14775.00, Position: 0
# Step: 3191, Balance: 14775.00, Position: 1
# Step: 3192, Balance: 14775.00, Position: 1
# Step: 3193, Balance: 14775.00, Position: 1
# Step: 3194, Balance: 14775.00, Position: 1
# Step: 3195, Balance: 14775.00, Position: 1
# Step: 3196, Balance: 14775.00, Position: 1
# Step: 3197, Balance: 14925.00, Position: 0
# Step: 3198, Balance: 14925.00, Position: 1
# Step: 3199, Balance: 14925.00, Position: 1
# Step: 3200, Balance: 14975.00, Position: 0
# Step: 3201, Balance: 14975.00, Position: -1
# Step: 3202, Balance: 14962.50, Position: 0
# Step: 3203, Balance: 14962.50, Position: 1
# Step: 3204, Balance: 14962.50, Position: 1
# Step: 3205, Balance: 14962.50, Position: 1
# Step: 3206, Balance: 14862.50, Position: 0
# Step: 3207, Balance: 14862.50, Position: 0
# Step: 3208, Balance: 14862.50, Position: -1
# Step: 3209, Balance: 14912.50, Position: 0
# Step: 3210, Balance: 14912.50, Position: -1
# Step: 3211, Balance: 14912.50, Position: -1
# Step: 3212, Balance: 14975.00, Position: 0
# Step: 3213, Balance: 14975.00, Position: 0
# Step: 3214, Balance: 14975.00, Position: 0
# Step: 3215, Balance: 14975.00, Position: 0
# Step: 3216, Balance: 14975.00, Position: 0
# Step: 3217, Balance: 14975.00, Position: 1
# Step: 3218, Balance: 14975.00, Position: 1
# Step: 3219, Balance: 14975.00, Position: 1
# Step: 3220, Balance: 14987.50, Position: 0
# Step: 3221, Balance: 14987.50, Position: 0
# Step: 3222, Balance: 14987.50, Position: -1
# Step: 3223, Balance: 14987.50, Position: -1
# Step: 3224, Balance: 14987.50, Position: -1
# Step: 3225, Balance: 14962.50, Position: 0
# Step: 3226, Balance: 14962.50, Position: 0
# Step: 3227, Balance: 14962.50, Position: -1
# Step: 3228, Balance: 14962.50, Position: -1
# Step: 3229, Balance: 14962.50, Position: -1
# Step: 3230, Balance: 14962.50, Position: -1
# Step: 3231, Balance: 14962.50, Position: -1
# Step: 3232, Balance: 14937.50, Position: 0
# Step: 3233, Balance: 14937.50, Position: 0
# Step: 3234, Balance: 14937.50, Position: -1
# Step: 3235, Balance: 14937.50, Position: -1
# Step: 3236, Balance: 14937.50, Position: 0
# Step: 3237, Balance: 14937.50, Position: 1
# Step: 3238, Balance: 14912.50, Position: 0
# Step: 3239, Balance: 14912.50, Position: 1
# Step: 3240, Balance: 14912.50, Position: 1
# Step: 3241, Balance: 14887.50, Position: 0
# Step: 3242, Balance: 14887.50, Position: 1
# Step: 3243, Balance: 14887.50, Position: 1
# Step: 3244, Balance: 14887.50, Position: 1
# Step: 3245, Balance: 14887.50, Position: 1
# Step: 3246, Balance: 14887.50, Position: 1
# Step: 3247, Balance: 14887.50, Position: 1
# Step: 3248, Balance: 14887.50, Position: 1
# Step: 3249, Balance: 14887.50, Position: 1
# Step: 3250, Balance: 14887.50, Position: 1
# Step: 3251, Balance: 14887.50, Position: 1
# Step: 3252, Balance: 14887.50, Position: 1
# Step: 3253, Balance: 14887.50, Position: 1
# Step: 3254, Balance: 14887.50, Position: 1
# Step: 3255, Balance: 14912.50, Position: 0
# Step: 3256, Balance: 14912.50, Position: 1
# Step: 3257, Balance: 14912.50, Position: 1
# Step: 3258, Balance: 14912.50, Position: 1
# Step: 3259, Balance: 14912.50, Position: 1
# Step: 3260, Balance: 14912.50, Position: 1
# Step: 3261, Balance: 14912.50, Position: 1
# Step: 3262, Balance: 14912.50, Position: 1
# Step: 3263, Balance: 14912.50, Position: 0
# Step: 3264, Balance: 14912.50, Position: 0
# Step: 3265, Balance: 14912.50, Position: 0
# Step: 3266, Balance: 14912.50, Position: 0
# Step: 3267, Balance: 14912.50, Position: 1
# Step: 3268, Balance: 14912.50, Position: 1
# Step: 3269, Balance: 14912.50, Position: 1
# Step: 3270, Balance: 14912.50, Position: 1
# Step: 3271, Balance: 14912.50, Position: 1
# Step: 3272, Balance: 14912.50, Position: 1
# Step: 3273, Balance: 14912.50, Position: 1
# Step: 3274, Balance: 14912.50, Position: 1
# Step: 3275, Balance: 14912.50, Position: 1
# Step: 3276, Balance: 14887.50, Position: 0
# Step: 3277, Balance: 14887.50, Position: 0
# Step: 3278, Balance: 14887.50, Position: 0
# Step: 3279, Balance: 14887.50, Position: 0
# Step: 3280, Balance: 14887.50, Position: 1
# Step: 3281, Balance: 14887.50, Position: 1
# Step: 3282, Balance: 14887.50, Position: 1
# Step: 3283, Balance: 14887.50, Position: 1
# Step: 3284, Balance: 14812.50, Position: 0
# Step: 3285, Balance: 14812.50, Position: 0
# Step: 3286, Balance: 14812.50, Position: 0
# Step: 3287, Balance: 14812.50, Position: 0
# Step: 3288, Balance: 14812.50, Position: 0
# Step: 3289, Balance: 14812.50, Position: 1
# Step: 3290, Balance: 14812.50, Position: 1
# Step: 3291, Balance: 14812.50, Position: 1
# Step: 3292, Balance: 14800.00, Position: 0
# Step: 3293, Balance: 14800.00, Position: 1
# Step: 3294, Balance: 14800.00, Position: 1
# Step: 3295, Balance: 14800.00, Position: 1
# Step: 3296, Balance: 14800.00, Position: 1
# Step: 3297, Balance: 14800.00, Position: 1
# Step: 3298, Balance: 14800.00, Position: 1
# Step: 3299, Balance: 14812.50, Position: 0
# Step: 3300, Balance: 14812.50, Position: 1
# Step: 3301, Balance: 14812.50, Position: 1
# Step: 3302, Balance: 14812.50, Position: 1
# Step: 3303, Balance: 14837.50, Position: 0
# Step: 3304, Balance: 14837.50, Position: 0
# Step: 3305, Balance: 14837.50, Position: 0
# Step: 3306, Balance: 14837.50, Position: -1
# Step: 3307, Balance: 14850.00, Position: 0
# Step: 3308, Balance: 14850.00, Position: 1
# Step: 3309, Balance: 14850.00, Position: 1
# Step: 3310, Balance: 14850.00, Position: 1
# Step: 3311, Balance: 14850.00, Position: 1
# Step: 3312, Balance: 14850.00, Position: 1
# Step: 3313, Balance: 14837.50, Position: 0
# Step: 3314, Balance: 14837.50, Position: 1
# Step: 3315, Balance: 14837.50, Position: 1
# Step: 3316, Balance: 14837.50, Position: 1
# Step: 3317, Balance: 14775.00, Position: 0
# Step: 3318, Balance: 14775.00, Position: 0
# Step: 3319, Balance: 14775.00, Position: 1
# Step: 3320, Balance: 14775.00, Position: 1
# Step: 3321, Balance: 14787.50, Position: 0
# Step: 3322, Balance: 14787.50, Position: 1
# Step: 3323, Balance: 14787.50, Position: 1
# Step: 3324, Balance: 14787.50, Position: 1
# Step: 3325, Balance: 14787.50, Position: 1
# Step: 3326, Balance: 14787.50, Position: 1
# Step: 3327, Balance: 14787.50, Position: 1
# Step: 3328, Balance: 14787.50, Position: 1
# Step: 3329, Balance: 14787.50, Position: 1
# Step: 3330, Balance: 14787.50, Position: 1
# Step: 3331, Balance: 14762.50, Position: 0
# Step: 3332, Balance: 14762.50, Position: 1
# Step: 3333, Balance: 14762.50, Position: 1
# Step: 3334, Balance: 14775.00, Position: 0
# Step: 3335, Balance: 14775.00, Position: 1
# Step: 3336, Balance: 14775.00, Position: 1
# Step: 3337, Balance: 14775.00, Position: 1
# Step: 3338, Balance: 14775.00, Position: 1
# Step: 3339, Balance: 14775.00, Position: 1
# Step: 3340, Balance: 14775.00, Position: 1
# Step: 3341, Balance: 14775.00, Position: 1
# Step: 3342, Balance: 14775.00, Position: 1
# Step: 3343, Balance: 14775.00, Position: 1
# Step: 3344, Balance: 14775.00, Position: 1
# Step: 3345, Balance: 14775.00, Position: 1
# Step: 3346, Balance: 14775.00, Position: 1
# Step: 3347, Balance: 14775.00, Position: 1
# Step: 3348, Balance: 14775.00, Position: 1
# Step: 3349, Balance: 14750.00, Position: 0
# Step: 3350, Balance: 14750.00, Position: -1
# Step: 3351, Balance: 14725.00, Position: 0
# Step: 3352, Balance: 14725.00, Position: 1
# Step: 3353, Balance: 14725.00, Position: 1
# Step: 3354, Balance: 14725.00, Position: 1
# Step: 3355, Balance: 14725.00, Position: 1
# Step: 3356, Balance: 14712.50, Position: 0
# Step: 3357, Balance: 14712.50, Position: 1
# Step: 3358, Balance: 14712.50, Position: 1
# Step: 3359, Balance: 14712.50, Position: 1
# Step: 3360, Balance: 14712.50, Position: 1
# Step: 3361, Balance: 14712.50, Position: 1
# Step: 3362, Balance: 14712.50, Position: 1
# Step: 3363, Balance: 14637.50, Position: 0
# Step: 3364, Balance: 14637.50, Position: 0
# Step: 3365, Balance: 14637.50, Position: 1
# Step: 3366, Balance: 14637.50, Position: 1
# Step: 3367, Balance: 14637.50, Position: 0
# Step: 3368, Balance: 14637.50, Position: 0
# Step: 3369, Balance: 14637.50, Position: 0
# Step: 3370, Balance: 14637.50, Position: 0
# Step: 3371, Balance: 14637.50, Position: 0
# Step: 3372, Balance: 14637.50, Position: 0
# Step: 3373, Balance: 14637.50, Position: 0
# Step: 3374, Balance: 14637.50, Position: 0
# Step: 3375, Balance: 14637.50, Position: 0
# Step: 3376, Balance: 14637.50, Position: 1
# Step: 3377, Balance: 14637.50, Position: 1
# Step: 3378, Balance: 14637.50, Position: 1
# Step: 3379, Balance: 14612.50, Position: 0
# Step: 3380, Balance: 14612.50, Position: 1
# Step: 3381, Balance: 14612.50, Position: 1
# Step: 3382, Balance: 14612.50, Position: 1
# Step: 3383, Balance: 14612.50, Position: 1
# Step: 3384, Balance: 14612.50, Position: 1
# Step: 3385, Balance: 14612.50, Position: 1
# Step: 3386, Balance: 14612.50, Position: 1
# Step: 3387, Balance: 14612.50, Position: 1
# Step: 3388, Balance: 14612.50, Position: 1
# Step: 3389, Balance: 14612.50, Position: 1
# Step: 3390, Balance: 14612.50, Position: 1
# Step: 3391, Balance: 14612.50, Position: 1
# Step: 3392, Balance: 14612.50, Position: 1
# Step: 3393, Balance: 14612.50, Position: 1
# Step: 3394, Balance: 14625.00, Position: 0
# Step: 3395, Balance: 14625.00, Position: 0
# Step: 3396, Balance: 14625.00, Position: 1
# Step: 3397, Balance: 14625.00, Position: 1
# Step: 3398, Balance: 14625.00, Position: 1
# Step: 3399, Balance: 14625.00, Position: 1
# Step: 3400, Balance: 14625.00, Position: 1
# Step: 3401, Balance: 14625.00, Position: 0
# Step: 3402, Balance: 14625.00, Position: 1
# Step: 3403, Balance: 14625.00, Position: 1
# Step: 3404, Balance: 14625.00, Position: 1
# Step: 3405, Balance: 14625.00, Position: 1
# Step: 3406, Balance: 14625.00, Position: 1
# Step: 3407, Balance: 14625.00, Position: 1
# Step: 3408, Balance: 14625.00, Position: 1
# Step: 3409, Balance: 14625.00, Position: 1
# Step: 3410, Balance: 14625.00, Position: 1
# Step: 3411, Balance: 14612.50, Position: 0
# Step: 3412, Balance: 14612.50, Position: 0
# Step: 3413, Balance: 14612.50, Position: -1
# Step: 3414, Balance: 14612.50, Position: -1
# Step: 3415, Balance: 14612.50, Position: 0
# Step: 3416, Balance: 14612.50, Position: 0
# Step: 3417, Balance: 14612.50, Position: 1
# Step: 3418, Balance: 14612.50, Position: 1
# Step: 3419, Balance: 14612.50, Position: 1
# Step: 3420, Balance: 14625.00, Position: 0
# Step: 3421, Balance: 14625.00, Position: 1
# Step: 3422, Balance: 14625.00, Position: 1
# Step: 3423, Balance: 14600.00, Position: 0
# Step: 3424, Balance: 14600.00, Position: -1
# Step: 3425, Balance: 14600.00, Position: 0
# Step: 3426, Balance: 14600.00, Position: 1
# Step: 3427, Balance: 14600.00, Position: 1
# Step: 3428, Balance: 14600.00, Position: 0
# Step: 3429, Balance: 14600.00, Position: 1
# Step: 3430, Balance: 14600.00, Position: 1
# Step: 3431, Balance: 14600.00, Position: 1
# Step: 3432, Balance: 14600.00, Position: 1
# Step: 3433, Balance: 14600.00, Position: 1
# Step: 3434, Balance: 14600.00, Position: 1
# Step: 3435, Balance: 14600.00, Position: 1
# Step: 3436, Balance: 14600.00, Position: 1
# Step: 3437, Balance: 14600.00, Position: 1
# Step: 3438, Balance: 14600.00, Position: 1
# Step: 3439, Balance: 14537.50, Position: 0
# Step: 3440, Balance: 14537.50, Position: 0
# Step: 3441, Balance: 14537.50, Position: 1
# Step: 3442, Balance: 14537.50, Position: 1
# Step: 3443, Balance: 14537.50, Position: 1
# Step: 3444, Balance: 14537.50, Position: 1
# Step: 3445, Balance: 14537.50, Position: 1
# Step: 3446, Balance: 14537.50, Position: 1
# Step: 3447, Balance: 14537.50, Position: 1
# Step: 3448, Balance: 14537.50, Position: 1
# Step: 3449, Balance: 14537.50, Position: 1
# Step: 3450, Balance: 14537.50, Position: 1
# Step: 3451, Balance: 14537.50, Position: 1
# Step: 3452, Balance: 14537.50, Position: 1
# Step: 3453, Balance: 14562.50, Position: 0
# Step: 3454, Balance: 14562.50, Position: 1
# Step: 3455, Balance: 14562.50, Position: 1
# Step: 3456, Balance: 14562.50, Position: 1
# Step: 3457, Balance: 14562.50, Position: 1
# Step: 3458, Balance: 14562.50, Position: 1
# Step: 3459, Balance: 14562.50, Position: 1
# Step: 3460, Balance: 14562.50, Position: 1
# Step: 3461, Balance: 14562.50, Position: 1
# Step: 3462, Balance: 14562.50, Position: 1
# Step: 3463, Balance: 14562.50, Position: 1
# Step: 3464, Balance: 14562.50, Position: 1
# Step: 3465, Balance: 14562.50, Position: 1
# Step: 3466, Balance: 14562.50, Position: 1
# Step: 3467, Balance: 14562.50, Position: 1
# Step: 3468, Balance: 14562.50, Position: 1
# Step: 3469, Balance: 14562.50, Position: 1
# Step: 3470, Balance: 14562.50, Position: 1
# Step: 3471, Balance: 14600.00, Position: 0
# Step: 3472, Balance: 14600.00, Position: 1
# Step: 3473, Balance: 14600.00, Position: 1
# Step: 3474, Balance: 14600.00, Position: 1
# Step: 3475, Balance: 14600.00, Position: 1
# Step: 3476, Balance: 14600.00, Position: 1
# Step: 3477, Balance: 14587.50, Position: 0
# Step: 3478, Balance: 14587.50, Position: 0
# Step: 3479, Balance: 14587.50, Position: 0
# Step: 3480, Balance: 14587.50, Position: 1
# Step: 3481, Balance: 14587.50, Position: 1
# Step: 3482, Balance: 14587.50, Position: 1
# Step: 3483, Balance: 14587.50, Position: 1
# Step: 3484, Balance: 14587.50, Position: 1
# Step: 3485, Balance: 14587.50, Position: 1
# Step: 3486, Balance: 14587.50, Position: 1
# Step: 3487, Balance: 14587.50, Position: 1
# Step: 3488, Balance: 14587.50, Position: 1
# Step: 3489, Balance: 14587.50, Position: 1
# Step: 3490, Balance: 14587.50, Position: 1
# Step: 3491, Balance: 14587.50, Position: 1
# Step: 3492, Balance: 14587.50, Position: 1
# Step: 3493, Balance: 14587.50, Position: 1
# Step: 3494, Balance: 14587.50, Position: 1
# Step: 3495, Balance: 14587.50, Position: 1
# Step: 3496, Balance: 14587.50, Position: 1
# Step: 3497, Balance: 14587.50, Position: 0
# Step: 3498, Balance: 14587.50, Position: 1
# Step: 3499, Balance: 14587.50, Position: 1
# Step: 3500, Balance: 14587.50, Position: 1
# Step: 3501, Balance: 14587.50, Position: 1
# Step: 3502, Balance: 14587.50, Position: 1
# Step: 3503, Balance: 14587.50, Position: 1
# Step: 3504, Balance: 14587.50, Position: 1
# Step: 3505, Balance: 14587.50, Position: 1
# Step: 3506, Balance: 14587.50, Position: 1
# Step: 3507, Balance: 14537.50, Position: 0
# Step: 3508, Balance: 14537.50, Position: 0
# Step: 3509, Balance: 14537.50, Position: 1
# Step: 3510, Balance: 14537.50, Position: 1
# Step: 3511, Balance: 14537.50, Position: 1
# Step: 3512, Balance: 14537.50, Position: 1
# Step: 3513, Balance: 14512.50, Position: 0
# Step: 3514, Balance: 14512.50, Position: 0
# Step: 3515, Balance: 14512.50, Position: 1
# Step: 3516, Balance: 14512.50, Position: 1
# Step: 3517, Balance: 14512.50, Position: 1
# Step: 3518, Balance: 14512.50, Position: 1
# Step: 3519, Balance: 14512.50, Position: 1
# Step: 3520, Balance: 14512.50, Position: 1
# Step: 3521, Balance: 14537.50, Position: 0
# Step: 3522, Balance: 14537.50, Position: 1
# Step: 3523, Balance: 14537.50, Position: 1
# Step: 3524, Balance: 14537.50, Position: 1
# Step: 3525, Balance: 14537.50, Position: 1
# Step: 3526, Balance: 14537.50, Position: 1
# Step: 3527, Balance: 14537.50, Position: 1
# Step: 3528, Balance: 14562.50, Position: 0
# Step: 3529, Balance: 14562.50, Position: 0
# Step: 3530, Balance: 14562.50, Position: 1
# Step: 3531, Balance: 14562.50, Position: 1
# Step: 3532, Balance: 14562.50, Position: 1
# Step: 3533, Balance: 14575.00, Position: 0
# Step: 3534, Balance: 14575.00, Position: 0
# Step: 3535, Balance: 14575.00, Position: 1
# Step: 3536, Balance: 14575.00, Position: 1
# Step: 3537, Balance: 14575.00, Position: 1
# Step: 3538, Balance: 14575.00, Position: 1
# Step: 3539, Balance: 14575.00, Position: 1
# Step: 3540, Balance: 14575.00, Position: 0
# Step: 3541, Balance: 14575.00, Position: 1
# Step: 3542, Balance: 14575.00, Position: 1
# Step: 3543, Balance: 14575.00, Position: 1
# Step: 3544, Balance: 14575.00, Position: 1
# Step: 3545, Balance: 14575.00, Position: 0
# Step: 3546, Balance: 14575.00, Position: 0
# Step: 3547, Balance: 14575.00, Position: 1
# Step: 3548, Balance: 14575.00, Position: 1
# Step: 3549, Balance: 14575.00, Position: 1
# Step: 3550, Balance: 14562.50, Position: 0
# Step: 3551, Balance: 14562.50, Position: 1
# Step: 3552, Balance: 14550.00, Position: 0
# Step: 3553, Balance: 14550.00, Position: 1
# Step: 3554, Balance: 14550.00, Position: 1
# Step: 3555, Balance: 14550.00, Position: 1
# Step: 3556, Balance: 14550.00, Position: 1
# Step: 3557, Balance: 14550.00, Position: 1
# Step: 3558, Balance: 14550.00, Position: 1
# Step: 3559, Balance: 14550.00, Position: 1
# Step: 3560, Balance: 14550.00, Position: 1

# %% [markdown]
# ## Displaying Final Trading Results
#
# This cell displays the final results of the trading simulation performed in the previous cell (Cell Block 10). It prints the agent's final balance and the total number of trades executed during the simulation.
#
# **Steps:**
#
# 1. **Print Final Balance:**
#    - `print(f"Final Balance: ${env.balance:.2f}")`: Prints the agent's final balance after the trading simulation. The balance is formatted to two decimal places using `:.2f`.
#
# 2. **Print Total Trades:**
#    - `print(f"Total Trades: {env.total_trades}")`: Prints the total number of trades the agent made during the simulation.
#
# **Summary:**
#
# This cell provides a basic summary of the trading agent's performance by showing its final balance and the number of trades executed. These metrics are a starting point for evaluating the profitability and efficiency of the trading strategy learned by the agent during training. Many more are needed...

# %%
print(f"Final Balance: ${env.balance:.2f}")
print(f"Total Trades: {env.total_trades}")
# Out:
# Final Balance: $14550.00
# Total Trades: 438
